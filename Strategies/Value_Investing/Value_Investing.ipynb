# %% [markdown]
# # Value Investing #
#
# _Value Investing_ is the strategy of analyzing stocks by their valuation and performance ratios, and investing in the stocks that are cheapest relative to these common measures.
#
# For this project, we are going to build an investing strategy that selects the 50 stocks with the best value metrics. From there, we will calculate recommended trades for an equal-weight portfolio.
#
# ***
# ## Library Imports

# %%
import numpy as np
import pandas as pd
import xlsxwriter

import yfinance as yf
# for the fundamental ratios it is easier to use yahoo_fin
import yahoo_fin.stock_info as si

import scipy.stats as stats 
import math

# this notebook contains future warnings which i wanted to be ignored
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# Can read in previously saved data here:

# %%
# just P/E ratio data
value_df = pd.read_csv("PE_Ratio.csv", index_col=0)

# all value data
value_df = pd.read_csv("Value_Dataframe.csv", index_col=0)

# %% [markdown]
# Can use AlphaVantage API for up-to-date market data:

# %%
import requests
from secrets import ALPHAVANTAGE_API_KEY

## this endpoint extracts the basic financials of the stock
symbol = "GOOGL"
api_url = f'https://www.alphavantage.co/query?function=OVERVIEW&symbol={symbol}&apikey={ALPHAVANTAGE_API_KEY}'
data = requests.get(api_url).json()

# %% [markdown]
# ## Importing our list of stocks

# %%
tickers = si.tickers_sp500()
tickers
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABT',
#  'ACGL',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'ANSS',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATO',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BALL',
#  'BAX',
#  'BBWI',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BF-B',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLK',
#  'BMY',
#  'BR',
#  'BRK-B',
#  'BRO',
#  'BSX',
#  'BWA',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDAY',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CEG',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMS',
#  'CNC',
#  'CNP',
#  'COF',
#  'COO',
#  'COP',
#  'COST',
#  'CPB',
#  'CPRT',
#  'CPT',
#  'CRL',
#  'CRM',
#  'CSCO',
#  'CSGP',
#  'CSX',
#  'CTAS',
#  'CTLT',
#  'CTRA',
#  'CTSH',
#  'CTVA',
#  'CVS',
#  'CVX',
#  'CZR',
#  'D',
#  'DAL',
#  'DD',
#  'DE',
#  'DFS',
#  'DG',
#  'DGX',
#  'DHI',
#  'DHR',
#  'DIS',
#  'DISH',
#  'DLR',
#  'DLTR',
#  'DOV',
#  'DOW',
#  'DPZ',
#  'DRI',
#  'DTE',
#  'DUK',
#  'DVA',
#  'DVN',
#  'DXC',
#  'DXCM',
#  'EA',
#  'EBAY',
#  'ECL',
#  'ED',
#  'EFX',
#  'EIX',
#  'EL',
#  'ELV',
#  'EMN',
#  'EMR',
#  'ENPH',
#  'EOG',
#  'EPAM',
#  'EQIX',
#  'EQR',
#  'EQT',
#  'ES',
#  'ESS',
#  'ETN',
#  'ETR',
#  'ETSY',
#  'EVRG',
#  'EW',
#  'EXC',
#  'EXPD',
#  'EXPE',
#  'EXR',
#  'F',
#  'FANG',
#  'FAST',
#  'FCX',
#  'FDS',
#  'FDX',
#  'FE',
#  'FFIV',
#  'FIS',
#  'FISV',
#  'FITB',
#  'FLT',
#  'FMC',
#  'FOX',
#  'FOXA',
#  'FRC',
#  'FRT',
#  'FSLR',
#  'FTNT',
#  'FTV',
#  'GD',
#  'GE',
#  'GEHC',
#  'GEN',
#  'GILD',
#  'GIS',
#  'GL',
#  'GLW',
#  'GM',
#  'GNRC',
#  'GOOG',
#  'GOOGL',
#  'GPC',
#  'GPN',
#  'GRMN',
#  'GS',
#  'GWW',
#  'HAL',
#  'HAS',
#  'HBAN',
#  'HCA',
#  'HD',
#  'HES',
#  'HIG',
#  'HII',
#  'HLT',
#  'HOLX',
#  'HON',
#  'HPE',
#  'HPQ',
#  'HRL',
#  'HSIC',
#  'HST',
#  'HSY',
#  'HUM',
#  'HWM',
#  'IBM',
#  'ICE',
#  'IDXX',
#  'IEX',
#  'IFF',
#  'ILMN',
#  'INCY',
#  'INTC',
#  'INTU',
#  'INVH',
#  'IP',
#  'IPG',
#  'IQV',
#  'IR',
#  'IRM',
#  'ISRG',
#  'IT',
#  'ITW',
#  'IVZ',
#  'J',
#  'JBHT',
#  'JCI',
#  'JKHY',
#  'JNJ',
#  'JNPR',
#  'JPM',
#  'K',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KHC',
#  'KIM',
#  'KLAC',
#  'KMB',
#  'KMI',
#  'KMX',
#  'KO',
#  'KR',
#  'L',
#  'LDOS',
#  'LEN',
#  'LH',
#  'LHX',
#  'LIN',
#  'LKQ',
#  'LLY',
#  'LMT',
#  'LNC',
#  'LNT',
#  'LOW',
#  'LRCX',
#  'LUMN',
#  'LUV',
#  'LVS',
#  'LW',
#  'LYB',
#  'LYV',
#  'MA',
#  'MAA',
#  'MAR',
#  'MAS',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'MDLZ',
#  'MDT',
#  'MET',
#  'META',
#  'MGM',
#  'MHK',
#  'MKC',
#  'MKTX',
#  'MLM',
#  'MMC',
#  'MMM',
#  'MNST',
#  'MO',
#  'MOH',
#  'MOS',
#  'MPC',
#  'MPWR',
#  'MRK',
#  'MRNA',
#  'MRO',
#  'MS',
#  'MSCI',
#  'MSFT',
#  'MSI',
#  'MTB',
#  'MTCH',
#  'MTD',
#  'MU',
#  'NCLH',
#  'NDAQ',
#  'NDSN',
#  'NEE',
#  'NEM',
#  'NFLX',
#  'NI',
#  'NKE',
#  'NOC',
#  'NOW',
#  'NRG',
#  'NSC',
#  'NTAP',
#  'NTRS',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NWL',
#  'NWS',
#  'NWSA',
#  'NXPI',
#  'O',
#  'ODFL',
#  'OGN',
#  'OKE',
#  'OMC',
#  'ON',
#  'ORCL',
#  'ORLY',
#  'OTIS',
#  'OXY',
#  'PARA',
#  'PAYC',
#  'PAYX',
#  'PCAR',
#  'PCG',
#  'PEAK',
#  'PEG',
#  'PEP',
#  'PFE',
#  'PFG',
#  'PG',
#  'PGR',
#  'PH',
#  'PHM',
#  'PKG',
#  'PKI',
#  'PLD',
#  'PM',
#  'PNC',
#  'PNR',
#  'PNW',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PRU',
#  'PSA',
#  'PSX',
#  'PTC',
#  'PWR',
#  'PXD',
#  'PYPL',
#  'QCOM',
#  'QRVO',
#  'RCL',
#  'RE',
#  'REG',
#  'REGN',
#  'RF',
#  'RHI',
#  'RJF',
#  'RL',
#  'RMD',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RSG',
#  'RTX',
#  'SBAC',
#  'SBNY',
#  'SBUX',
#  'SCHW',
#  'SEDG',
#  'SEE',
#  'SHW',
#  'SIVB',
#  'SJM',
#  'SLB',
#  'SNA',
#  'SNPS',
#  'SO',
#  'SPG',
#  'SPGI',
#  'SRE',
#  'STE',
#  'STLD',
#  'STT',
#  'STX',
#  'STZ',
#  'SWK',
#  'SWKS',
#  'SYF',
#  'SYK',
#  'SYY',
#  'T',
#  'TAP',
#  'TDG',
#  'TDY',
#  'TECH',
#  'TEL',
#  'TER',
#  'TFC',
#  'TFX',
#  'TGT',
#  'TJX',
#  'TMO',
#  'TMUS',
#  'TPR',
#  'TRGP',
#  'TRMB',
#  'TROW',
#  'TRV',
#  'TSCO',
#  'TSLA',
#  'TSN',
#  'TT',
#  'TTWO',
#  'TXN',
#  'TXT',
#  'TYL',
#  'UAL',
#  'UDR',
#  'UHS',
#  'ULTA',
#  'UNH',
#  'UNP',
#  'UPS',
#  'URI',
#  'USB',
#  'V',
#  'VFC',
#  'VICI',
#  'VLO',
#  'VMC',
#  'VRSK',
#  'VRSN',
#  'VRTX',
#  'VTR',
#  'VTRS',
#  'VZ',
#  'WAB',
#  'WAT',
#  'WBA',
#  'WBD',
#  'WDC',
#  'WEC',
#  'WELL',
#  'WFC',
#  'WHR',
#  'WM',
#  'WMB',
#  'WMT',
#  'WRB',
#  'WRK',
#  'WST',
#  'WTW',
#  'WY',
#  'WYNN',
#  'XEL',
#  'XOM',
#  'XRAY',
#  'XYL',
#  'YUM',
#  'ZBH',
#  'ZBRA',
#  'ZION',
#  'ZTS']

# %% [markdown]
# ***
# ## Getting Market Data
#
# We now pull the required market data from yahoo_fin package.
#
# ### Building the data frame ###
#
# We build the data frame and loop through our tickers to extract the trailing P/E ratio, as well as the price.

# %%
## THIS BLOCK TAKES APPROX 40 MINS TO RUN
# Note that yahoo_fin uses .append method from pandas, which may be 
# depreciated one day...the warning has been suppressed here

my_columns = ["Ticker", "Price", "P/E Ratio", "NumberSharesToBuy"]
value_df = pd.DataFrame(columns=my_columns)

# initialise parameters for progress bar
i = 0
n = len(tickers)

for tick in tickers:
    ## Timer if wanted
    i += 1
    p = np.round((100*i)/n)
    print(f"{p}% completed,", tick)

    # try getting the required data
    try:
        stock = si.get_quote_table(tick)
        price = stock["Quote Price"]
        pe_ratio = stock["PE Ratio (TTM)"]
        
        # build row to add to the dataframe
        row = pd.Series([tick, price, pe_ratio, 'N/A'], index = my_columns)
        value_df = pd.concat([value_df, row.to_frame().T], ignore_index=True)
    except:
        print("Error with: ", tick)

value_df.to_csv("PE_Ratio.csv")
# Out:
# 0.0% completed, A
# 0.0% completed, AAL
# 1.0% completed, AAP
# 1.0% completed, AAPL
# 1.0% completed, ABBV
# 1.0% completed, ABC
# 1.0% completed, ABT
# Error with:  ABT
# 2.0% completed, ACGL
# 2.0% completed, ACN
# 2.0% completed, ADBE
# 2.0% completed, ADI
# 2.0% completed, ADM

# %% [markdown]
# ### Removing Glamour Stocks
#
# The opposite of a value stock is a "glamour stock".
#
# Since the goal of this strategy is to identify the 50 best value stocks from our universe, our next step is to remove glamour stocks from the dataframe.
#
# We sort the dataframe by the P/E ratio and drop all stocks outside the top 50.

# %%
## Best value means the smallest P/E ratio
value_df.sort_values("P/E Ratio", ascending=True, inplace=True)

## if some ratios were negative, could remove them here

top_50_pe = value_df[:50]
top_50_pe.reset_index(inplace=True, drop=True)

# view the new dataframe
top_50_pe
# Out:
#    Ticker       Price  P/E Ratio  NumberSharesToBuy
# 0   GOOGL   96.985001       1.29                NaN
# 1    GOOG   98.035004       1.31                NaN
# 2     MHK  115.900002       2.32                NaN
# 3     AIG   63.200100       3.75                NaN
# 4     APA   44.270000       4.19                NaN
# 5    CTRA   24.770000       4.50                NaN
# 6    DISH   13.985000       4.65                NaN
# 7     OGN   29.559999       4.95                NaN
# 8      CF   82.680000       5.40                NaN
# 9     DHI   95.440002       5.93                NaN
# 10   INTC   27.905001       6.26                NaN
# 11    COF  115.820000       6.47                NaN
# 12    WHR  153.229996       7.15                NaN
# 13      C   51.884998       7.30                NaN
# 14    DFS  115.529999       7.45                NaN
# 15     CE  122.070000       8.05                NaN
# 16     GM   36.426601       8.41                NaN
# 17    CMA   71.589996       8.45                NaN
# 18    PNC  162.699997       8.50                NaN
# 19    SWK   84.930000       8.63                NaN
# 20    COP  120.599998       8.67                NaN
# 21     GS  358.299988       8.90                NaN
# 22     VZ   41.115002       9.01                NaN
# 23    DOW   58.035000       9.24                NaN
# 24    AFL   72.980003       9.33                NaN
# 25    PHM   52.044998       9.34                NaN
# 26     LH  251.597504       9.36                NaN
# 27    KIM   22.215000       9.41                NaN
# 28   TROW  113.555000       9.64                NaN
# 29   NDAQ   59.560001       9.69                NaN
# 30   SIVB  294.540009       9.69                NaN
# 31    CVX  173.820007       9.89                NaN
# 32    SYF   36.209999      10.18                NaN
# 33    LEN   99.559998      10.18                NaN
# 34    CFG   42.294998      10.32                NaN
# 35   CARR   43.654999      10.52                NaN
# 36   ZION   52.169998      10.61                NaN
# 37    KEY   18.754999      10.61                NaN
# 38    ADM   82.279999      10.67                NaN
# 39   SBNY  122.779999      10.83                NaN
# 40    JPM  139.169998      11.04                NaN
# 41    BAC   35.285000      11.06                NaN
# 42   HOLX   82.099998      11.27                NaN
# 43    TFC   48.555000      11.46                NaN
# 44    TSN   64.070000      11.57                NaN
# 45    MMM  113.190002      11.58                NaN
# 46   CHRW   96.730003      11.72                NaN
# 47   BBWI   44.305000      11.78                NaN
# 48   EBAY   48.755001      11.82                NaN
# 49    IVZ   18.135000      11.86                NaN

# %% [markdown]
# ### Calculating the number of shares to buy
#
# We define useful functions to extract portfolio size and then calculate the number of shares to buy, before adding it to the column of the dataframe.

# %%
def portfolio_size_input():
    # Get portfolio size
    portfolio_size = input("Enter the value of your portfolio:")
    try: 
        portfolio_size = float(portfolio_size)
    except ValueError:
        print("Portfolio Size is not a valid number.\n")

    return portfolio_size


def number_shares_to_buy(portfolio_size, portfolio):
    value = portfolio_size/len(portfolio.index)
    # loop through top_50 and place number of shares
    for i in range(0,len(portfolio)) :
        portfolio.loc[i,"NumberSharesToBuy"] = math.floor(value/portfolio.loc[i,"Price"])

# %%
portfolio_size = portfolio_size_input()

# add to the datafram column
number_shares_to_buy(portfolio_size, top_50_pe)

# view the updated dataframe
top_50_pe
# Out:
#    Ticker       Price  P/E Ratio  NumberSharesToBuy
# 0   GOOGL   96.985001       1.29              206.0
# 1    GOOG   98.035004       1.31              204.0
# 2     MHK  115.900002       2.32              172.0
# 3     AIG   63.200100       3.75              316.0
# 4     APA   44.270000       4.19              451.0
# 5    CTRA   24.770000       4.50              807.0
# 6    DISH   13.985000       4.65             1430.0
# 7     OGN   29.559999       4.95              676.0
# 8      CF   82.680000       5.40              241.0
# 9     DHI   95.440002       5.93              209.0
# 10   INTC   27.905001       6.26              716.0
# 11    COF  115.820000       6.47              172.0
# 12    WHR  153.229996       7.15              130.0
# 13      C   51.884998       7.30              385.0
# 14    DFS  115.529999       7.45              173.0
# 15     CE  122.070000       8.05              163.0
# 16     GM   36.426601       8.41              549.0
# 17    CMA   71.589996       8.45              279.0
# 18    PNC  162.699997       8.50              122.0
# 19    SWK   84.930000       8.63              235.0
# 20    COP  120.599998       8.67              165.0
# 21     GS  358.299988       8.90               55.0
# 22     VZ   41.115002       9.01              486.0
# 23    DOW   58.035000       9.24              344.0
# 24    AFL   72.980003       9.33              274.0
# 25    PHM   52.044998       9.34              384.0
# 26     LH  251.597504       9.36               79.0
# 27    KIM   22.215000       9.41              900.0
# 28   TROW  113.555000       9.64              176.0
# 29   NDAQ   59.560001       9.69              335.0
# 30   SIVB  294.540009       9.69               67.0
# 31    CVX  173.820007       9.89              115.0
# 32    SYF   36.209999      10.18              552.0
# 33    LEN   99.559998      10.18              200.0
# 34    CFG   42.294998      10.32              472.0
# 35   CARR   43.654999      10.52              458.0
# 36   ZION   52.169998      10.61              383.0
# 37    KEY   18.754999      10.61             1066.0
# 38    ADM   82.279999      10.67              243.0
# 39   SBNY  122.779999      10.83              162.0
# 40    JPM  139.169998      11.04              143.0
# 41    BAC   35.285000      11.06              566.0
# 42   HOLX   82.099998      11.27              243.0
# 43    TFC   48.555000      11.46              411.0
# 44    TSN   64.070000      11.57              312.0
# 45    MMM  113.190002      11.58              176.0
# 46   CHRW   96.730003      11.72              206.0
# 47   BBWI   44.305000      11.78              451.0
# 48   EBAY   48.755001      11.82              410.0
# 49    IVZ   18.135000      11.86             1102.0

# %% [markdown]
# ***
# ## Building a Better (and more realistic) Value Investment Strategy
#
# Every valuation metric has certain flaws. For example, the P/E ratio doesn't work well with stocks that have negative earnings, like tech start-ups.
#
# Similarly, stocks that buyback their own shares are difficult to value using the P/B ratio (price-to-book).
#
# Investors typically use a `composite` basket of valuation metrics to build a robust quantitative value strategy.
#
# In this next section, we will filter stocks with the lowest percentiles on the following metrics:
#
# - P/E ratio
# - P/B ratio
# - Price-to-sales ratio
# - EV-to-EBITDA (Enterprise Value to Earnings Before Interest, Tax, Depreciations and Amortizations)
# - EV-to-Gross Profit
#
# Not all of these ratios are provided by the API and instead will require computation once we have pulled the raw data.

# %%
my_columns = [
    "Ticker",
    "Price",
    "P/E Ratio",
    "P/E Percentile",
    "P/B Ratio",
    "P/B Percentile",
    "P/Sales Ratio",
    "P/Sales Percentile",
    "EV/EBITDA Ratio",
    "EV/EBITDA Percentile",
    "EV/Gross Ratio",
    "EV/Gross Percentile",
    "NumberSharesToBuy"
]

value_df = pd.DataFrame(columns=my_columns)

# %% [markdown]
# Now we can get market data to complete the data frame.

# %%
## THIS BLOCK TAKES APPROX 80 MINS TO RUN
## Data can be loaded above
i = 0
n = len(tickers)

for tick in tickers:
    i += 1
    p = np.round((100*i)/n)
    print(f"{p}% completed,", tick)
    try:
        stock = si.get_stats_valuation(tick).iloc[:,0:2]
        price = si.get_quote_table(tick)["Quote Price"]
        pe_ratio = float(stock.iloc[2,1])
        pb_ratio = float(stock.iloc[6,1])
        ps_ratio = float(stock.iloc[5,1])
        ev_ebitda = float(stock.iloc[8,1])
        ev_gross = float(stock.iloc[7,1])

        row = pd.Series([tick, price, pe_ratio, 'N/A', 
                        pb_ratio, "N/A", ps_ratio, "N/A",
                        ev_ebitda, "N/A", ev_gross, "N/A", "N/A"], index = my_columns)
        value_df = pd.concat([value_df, row.to_frame().T], ignore_index=True)
    except:
        print("Error with: ", tick)

value_df.to_csv("Value_Dataframe.csv")
# Out:
# 0.0% completed, A
# 0.0% completed, AAL
# 1.0% completed, AAP
# 1.0% completed, AAPL
# 1.0% completed, ABBV
# 1.0% completed, ABC
# 1.0% completed, ABT
# 2.0% completed, ACGL
# 2.0% completed, ACN
# 2.0% completed, ADBE
# 2.0% completed, ADI
# 2.0% completed, ADM
# 3.0% completed, ADP
# 3.0% completed, ADSK
# 3.0% completed, AEE
# 3.0% completed, AEP
# 3.0% completed, AES
# 4.0% completed, AFL
# 4.0% completed, AIG
# 4.0% completed, AIZ
# 4.0% completed, AJG
# 4.0% completed, AKAM
# 5.0% completed, ALB
# 5.0% completed, ALGN
# 5.0% completed, ALK
# 5.0% completed, ALL
# 5.0% completed, ALLE
# 6.0% completed, AMAT
# 6.0% completed, AMCR
# 6.0% completed, AMD
# 6.0% completed, AME
# 6.0% completed, AMGN
# 7.0% completed, AMP
# 7.0% completed, AMT
# 7.0% completed, AMZN
# 7.0% completed, ANET
# 7.0% completed, ANSS
# 8.0% completed, AON
# 8.0% completed, AOS
# 8.0% completed, APA
# 8.0% completed, APD
# 8.0% completed, APH
# 9.0% completed, APTV
# 9.0% completed, ARE
# 9.0% completed, ATO
# 9.0% completed, ATVI
# 9.0% completed, AVB
# 10.0% completed, AVGO
# 10.0% completed, AVY
# 10.0% completed, AWK
# 10.0% completed, AXP
# 10.0% completed, AZO
# 11.0% completed, BA
# 11.0% completed, BAC
# 11.0% completed, BALL
# 11.0% completed, BAX
# 11.0% completed, BBWI
# 12.0% completed, BBY
# 12.0% completed, BDX
# 12.0% completed, BEN
# 12.0% completed, BF-B
# 12.0% completed, BIIB
# 13.0% completed, BIO
# 13.0% completed, BK
# 13.0% completed, BKNG
# 13.0% completed, BKR
# 13.0% completed, BLK
# 14.0% completed, BMY
# 14.0% completed, BR
# 14.0% completed, BRK-B
# 14.0% completed, BRO
# 14.0% completed, BSX
# 15.0% completed, BWA
# 15.0% completed, BXP
# 15.0% completed, C
# 15.0% completed, CAG
# 15.0% completed, CAH
# 16.0% completed, CARR
# 16.0% completed, CAT
# 16.0% completed, CB
# 16.0% completed, CBOE
# 16.0% completed, CBRE
# 17.0% completed, CCI
# 17.0% completed, CCL
# 17.0% completed, CDAY
# 17.0% completed, CDNS
# 17.0% completed, CDW
# 17.0% completed, CE
# 18.0% completed, CEG
# 18.0% completed, CF
# 18.0% completed, CFG
# 18.0% completed, CHD
# 18.0% completed, CHRW
# 19.0% completed, CHTR
# 19.0% completed, CI
# 19.0% completed, CINF
# 19.0% completed, CL
# 19.0% completed, CLX
# 20.0% completed, CMA
# 20.0% completed, CMCSA
# 20.0% completed, CME
# 20.0% completed, CMG
# 20.0% completed, CMI
# 21.0% completed, CMS
# 21.0% completed, CNC
# 21.0% completed, CNP
# 21.0% completed, COF
# 21.0% completed, COO
# 22.0% completed, COP
# 22.0% completed, COST
# 22.0% completed, CPB
# 22.0% completed, CPRT
# 22.0% completed, CPT
# 23.0% completed, CRL
# 23.0% completed, CRM
# 23.0% completed, CSCO
# 23.0% completed, CSGP
# 23.0% completed, CSX
# 24.0% completed, CTAS
# 24.0% completed, CTLT
# 24.0% completed, CTRA
# 24.0% completed, CTSH
# 24.0% completed, CTVA
# 25.0% completed, CVS
# 25.0% completed, CVX
# 25.0% completed, CZR
# 25.0% completed, D
# 25.0% completed, DAL
# 26.0% completed, DD
# 26.0% completed, DE
# 26.0% completed, DFS
# 26.0% completed, DG
# 26.0% completed, DGX
# 27.0% completed, DHI
# 27.0% completed, DHR
# 27.0% completed, DIS
# 27.0% completed, DISH
# 27.0% completed, DLR
# 28.0% completed, DLTR
# 28.0% completed, DOV
# 28.0% completed, DOW
# 28.0% completed, DPZ
# 28.0% completed, DRI
# 29.0% completed, DTE
# 29.0% completed, DUK
# 29.0% completed, DVA
# 29.0% completed, DVN
# 29.0% completed, DXC
# 30.0% completed, DXCM
# 30.0% completed, EA
# 30.0% completed, EBAY
# 30.0% completed, ECL
# 30.0% completed, ED
# 31.0% completed, EFX
# 31.0% completed, EIX
# 31.0% completed, EL
# 31.0% completed, ELV
# 31.0% completed, EMN
# 32.0% completed, EMR
# 32.0% completed, ENPH
# 32.0% completed, EOG
# 32.0% completed, EPAM
# 32.0% completed, EQIX
# 33.0% completed, EQR
# 33.0% completed, EQT
# 33.0% completed, ES
# 33.0% completed, ESS
# 33.0% completed, ETN
# 34.0% completed, ETR
# 34.0% completed, ETSY
# 34.0% completed, EVRG
# 34.0% completed, EW
# 34.0% completed, EXC
# 35.0% completed, EXPD
# 35.0% completed, EXPE
# 35.0% completed, EXR
# 35.0% completed, F
# 35.0% completed, FANG
# 36.0% completed, FAST
# 36.0% completed, FCX
# 36.0% completed, FDS
# 36.0% completed, FDX
# 36.0% completed, FE
# 37.0% completed, FFIV
# 37.0% completed, FIS
# 37.0% completed, FISV
# 37.0% completed, FITB
# 37.0% completed, FLT
# 38.0% completed, FMC
# 38.0% completed, FOX
# 38.0% completed, FOXA
# 38.0% completed, FRC
# 38.0% completed, FRT
# 39.0% completed, FSLR
# 39.0% completed, FTNT
# 39.0% completed, FTV
# 39.0% completed, GD
# 39.0% completed, GE
# 40.0% completed, GEHC
# 40.0% completed, GEN
# 40.0% completed, GILD
# 40.0% completed, GIS
# 40.0% completed, GL
# 41.0% completed, GLW
# 41.0% completed, GM
# 41.0% completed, GNRC
# 41.0% completed, GOOG
# 41.0% completed, GOOGL
# 42.0% completed, GPC
# Error with:  GPC
# 42.0% completed, GPN
# 42.0% completed, GRMN
# 42.0% completed, GS
# Error with:  GS
# 42.0% completed, GWW
# 43.0% completed, HAL
# 43.0% completed, HAS
# 43.0% completed, HBAN
# 43.0% completed, HCA
# 43.0% completed, HD
# 44.0% completed, HES
# 44.0% completed, HIG
# 44.0% completed, HII
# 44.0% completed, HLT
# 44.0% completed, HOLX
# Error with:  HOLX
# 45.0% completed, HON
# 45.0% completed, HPE
# 45.0% completed, HPQ
# 45.0% completed, HRL
# 45.0% completed, HSIC
# 46.0% completed, HST
# 46.0% completed, HSY
# 46.0% completed, HUM
# 46.0% completed, HWM
# 46.0% completed, IBM
# 47.0% completed, ICE
# 47.0% completed, IDXX
# 47.0% completed, IEX
# 47.0% completed, IFF
# 47.0% completed, ILMN
# 48.0% completed, INCY
# 48.0% completed, INTC
# 48.0% completed, INTU
# 48.0% completed, INVH
# 48.0% completed, IP
# 49.0% completed, IPG
# 49.0% completed, IQV
# 49.0% completed, IR
# 49.0% completed, IRM
# 49.0% completed, ISRG
# 50.0% completed, IT
# 50.0% completed, ITW
# 50.0% completed, IVZ
# 50.0% completed, J
# 50.0% completed, JBHT
# 50.0% completed, JCI
# 51.0% completed, JKHY
# 51.0% completed, JNJ
# 51.0% completed, JNPR
# 51.0% completed, JPM
# 51.0% completed, K
# 52.0% completed, KDP
# 52.0% completed, KEY
# 52.0% completed, KEYS
# 52.0% completed, KHC
# 52.0% completed, KIM
# 53.0% completed, KLAC
# 53.0% completed, KMB
# 53.0% completed, KMI
# 53.0% completed, KMX
# 53.0% completed, KO
# 54.0% completed, KR
# 54.0% completed, L
# 54.0% completed, LDOS
# 54.0% completed, LEN
# 54.0% completed, LH
# 55.0% completed, LHX
# 55.0% completed, LIN
# 55.0% completed, LKQ
# 55.0% completed, LLY
# 55.0% completed, LMT
# 56.0% completed, LNC
# 56.0% completed, LNT
# 56.0% completed, LOW
# 56.0% completed, LRCX
# 56.0% completed, LUMN
# 57.0% completed, LUV
# 57.0% completed, LVS
# 57.0% completed, LW
# 57.0% completed, LYB
# 57.0% completed, LYV
# 58.0% completed, MA
# 58.0% completed, MAA
# 58.0% completed, MAR
# 58.0% completed, MAS
# 58.0% completed, MCD
# 59.0% completed, MCHP
# 59.0% completed, MCK
# 59.0% completed, MCO
# 59.0% completed, MDLZ
# 59.0% completed, MDT
# 60.0% completed, MET
# 60.0% completed, META
# 60.0% completed, MGM
# 60.0% completed, MHK
# 60.0% completed, MKC
# 61.0% completed, MKTX
# 61.0% completed, MLM
# 61.0% completed, MMC
# 61.0% completed, MMM
# 61.0% completed, MNST
# 62.0% completed, MO
# 62.0% completed, MOH
# 62.0% completed, MOS
# 62.0% completed, MPC
# 62.0% completed, MPWR
# 63.0% completed, MRK
# 63.0% completed, MRNA
# 63.0% completed, MRO
# 63.0% completed, MS
# 63.0% completed, MSCI
# 64.0% completed, MSFT
# 64.0% completed, MSI
# 64.0% completed, MTB
# 64.0% completed, MTCH
# 64.0% completed, MTD
# 65.0% completed, MU
# 65.0% completed, NCLH
# 65.0% completed, NDAQ
# 65.0% completed, NDSN
# 65.0% completed, NEE
# 66.0% completed, NEM
# 66.0% completed, NFLX
# 66.0% completed, NI
# 66.0% completed, NKE
# 66.0% completed, NOC
# 67.0% completed, NOW
# 67.0% completed, NRG
# 67.0% completed, NSC
# 67.0% completed, NTAP
# 67.0% completed, NTRS
# 68.0% completed, NUE
# 68.0% completed, NVDA
# 68.0% completed, NVR
# 68.0% completed, NWL
# 68.0% completed, NWS
# 69.0% completed, NWSA
# 69.0% completed, NXPI
# 69.0% completed, O
# 69.0% completed, ODFL
# 69.0% completed, OGN
# 70.0% completed, OKE
# 70.0% completed, OMC
# 70.0% completed, ON
# 70.0% completed, ORCL
# 70.0% completed, ORLY
# 71.0% completed, OTIS
# 71.0% completed, OXY
# 71.0% completed, PARA
# 71.0% completed, PAYC
# 71.0% completed, PAYX
# 72.0% completed, PCAR
# 72.0% completed, PCG
# 72.0% completed, PEAK
# 72.0% completed, PEG
# 72.0% completed, PEP
# 73.0% completed, PFE
# Error with:  PFE
# 73.0% completed, PFG
# 73.0% completed, PG
# 73.0% completed, PGR
# 73.0% completed, PH
# 74.0% completed, PHM
# 74.0% completed, PKG
# 74.0% completed, PKI
# 74.0% completed, PLD
# 74.0% completed, PM
# 75.0% completed, PNC
# 75.0% completed, PNR
# 75.0% completed, PNW
# 75.0% completed, POOL
# 75.0% completed, PPG
# 76.0% completed, PPL
# 76.0% completed, PRU
# 76.0% completed, PSA
# 76.0% completed, PSX
# 76.0% completed, PTC
# 77.0% completed, PWR
# 77.0% completed, PXD
# 77.0% completed, PYPL
# 77.0% completed, QCOM
# 77.0% completed, QRVO
# 78.0% completed, RCL
# 78.0% completed, RE
# 78.0% completed, REG
# 78.0% completed, REGN
# 78.0% completed, RF
# 79.0% completed, RHI
# 79.0% completed, RJF
# 79.0% completed, RL
# 79.0% completed, RMD
# 79.0% completed, ROK
# 80.0% completed, ROL
# 80.0% completed, ROP
# 80.0% completed, ROST
# 80.0% completed, RSG
# 80.0% completed, RTX
# 81.0% completed, SBAC
# 81.0% completed, SBNY
# 81.0% completed, SBUX
# 81.0% completed, SCHW
# 81.0% completed, SEDG
# 82.0% completed, SEE
# 82.0% completed, SHW
# 82.0% completed, SIVB
# 82.0% completed, SJM
# 82.0% completed, SLB
# 83.0% completed, SNA
# 83.0% completed, SNPS
# 83.0% completed, SO
# 83.0% completed, SPG
# 83.0% completed, SPGI
# 83.0% completed, SRE
# 84.0% completed, STE
# 84.0% completed, STLD
# 84.0% completed, STT
# 84.0% completed, STX
# 84.0% completed, STZ
# 85.0% completed, SWK
# 85.0% completed, SWKS
# 85.0% completed, SYF
# 85.0% completed, SYK
# 85.0% completed, SYY
# 86.0% completed, T
# 86.0% completed, TAP
# 86.0% completed, TDG
# 86.0% completed, TDY
# 86.0% completed, TECH
# 87.0% completed, TEL
# 87.0% completed, TER
# 87.0% completed, TFC
# 87.0% completed, TFX
# 87.0% completed, TGT
# 88.0% completed, TJX
# 88.0% completed, TMO
# 88.0% completed, TMUS
# 88.0% completed, TPR
# 88.0% completed, TRGP
# 89.0% completed, TRMB
# 89.0% completed, TROW
# 89.0% completed, TRV
# 89.0% completed, TSCO
# 89.0% completed, TSLA
# 90.0% completed, TSN
# 90.0% completed, TT
# 90.0% completed, TTWO
# 90.0% completed, TXN
# 90.0% completed, TXT
# 91.0% completed, TYL
# 91.0% completed, UAL
# 91.0% completed, UDR
# 91.0% completed, UHS
# 91.0% completed, ULTA
# 92.0% completed, UNH
# 92.0% completed, UNP
# 92.0% completed, UPS
# 92.0% completed, URI
# 92.0% completed, USB
# 93.0% completed, V
# 93.0% completed, VFC
# 93.0% completed, VICI
# 93.0% completed, VLO
# 93.0% completed, VMC
# 94.0% completed, VRSK
# 94.0% completed, VRSN
# 94.0% completed, VRTX
# 94.0% completed, VTR
# 94.0% completed, VTRS
# 95.0% completed, VZ
# 95.0% completed, WAB
# 95.0% completed, WAT
# 95.0% completed, WBA
# 95.0% completed, WBD
# 96.0% completed, WDC
# 96.0% completed, WEC
# 96.0% completed, WELL
# 96.0% completed, WFC
# 96.0% completed, WHR
# 97.0% completed, WM
# 97.0% completed, WMB
# 97.0% completed, WMT
# 97.0% completed, WRB
# 97.0% completed, WRK
# 98.0% completed, WST
# 98.0% completed, WTW
# 98.0% completed, WY
# 98.0% completed, WYNN
# 98.0% completed, XEL
# 99.0% completed, XOM
# 99.0% completed, XRAY
# 99.0% completed, XYL
# 99.0% completed, YUM
# 99.0% completed, ZBH
# 100.0% completed, ZBRA
# 100.0% completed, ZION
# 100.0% completed, ZTS

# %% [markdown]
# ### Dealing with Missing Data
#
# If the dataframe contains some missing data because all of the metrics we require are not available through the API, then we can use the pandas `isnull` method to identify data.
#
# Dealing with missing data is an important topic of data science. There are two main approaches:
#
# - Drop missing data from the data set (pandas' `dropna` method is useful here).
# - Replace missing data with a new value (pandas `fillna` method is useful here).
#
# In this project, we will replace any missing data with the average non`NaN` data point from that column. Here's the code to do this:

# %%
value_df[value_df.isnull().any(axis=1)]
## Return a modified version of dataframe with rows that contain missing data
# Out:
#     Ticker       Price P/E Ratio P/E Percentile P/B Ratio P/B Percentile  \
# 1      AAL       16.91      2.81            N/A       NaN            N/A
# 7     ACGL   64.074997     19.66            N/A      2.07            N/A
# 16     AES   26.014999       NaN            N/A      6.89            N/A
# 17     AFL      70.625     10.46            N/A       1.9            N/A
# 18     AIG       60.73      3.63            N/A      1.17            N/A
# ..     ...         ...       ...            ...       ...            ...
# 494    YUM  131.419998       NaN            N/A       NaN            N/A
# 495    ZBH  130.759995       NaN            N/A       NaN            N/A
# 496   ZBRA  325.540009       NaN            N/A       NaN            N/A
# 497   ZION       53.34       NaN            N/A       NaN            N/A
# 498    ZTS  162.070007       NaN            N/A       NaN            N/A
#
#     P/Sales Ratio P/Sales Percentile EV/EBITDA Ratio EV/EBITDA Percentile  \
# 1             NaN                N/A             NaN                  N/A
# 7            2.61                N/A             NaN                  N/A
# 16           1.45                N/A           29.46                  N/A
# 17           2.25                N/A             NaN                  N/A
# 18           0.84                N/A             NaN                  N/A
# ..            ...                ...             ...                  ...
# 494           NaN                N/A             NaN                  N/A
# 495           NaN                N/A             NaN                  N/A
# 496           NaN                N/A             NaN                  N/A
# 497           NaN                N/A             NaN                  N/A
# 498           NaN                N/A             NaN                  N/A
#
#     EV/Gross Ratio EV/Gross Percentile NumberSharesToBuy
# 1              NaN                 N/A               N/A
# 7             2.86                 N/A               N/A
# 16            3.13                 N/A               N/A
# 17            2.32                 N/A               N/A
# 18            1.25                 N/A               N/A
# ..             ...                 ...               ...
# 494            NaN                 N/A               N/A
# 495            NaN                 N/A               N/A
# 496            NaN                 N/A               N/A
# 497            NaN                 N/A               N/A
# 498            NaN                 N/A               N/A
#
# [425 rows x 13 columns]

# %%
for column in ["P/E Ratio","P/B Ratio", "P/Sales Ratio","EV/EBITDA Ratio","EV/Gross Ratio"]:
    value_df[column].fillna(value_df[column].mean(), inplace=True)

value_df
# Out:
#     Ticker       Price  P/E Ratio P/E Percentile  P/B Ratio P/B Percentile  \
# 0        A  154.690002  37.190000            N/A   8.680000            N/A
# 1      AAL       16.91   2.810000            N/A  11.559886            N/A
# 2      AAP  149.059998  20.110000            N/A   3.420000            N/A
# 3     AAPL  151.759995  25.610000            N/A  42.100000            N/A
# 4     ABBV  144.550003  19.310000            N/A  16.020000            N/A
# ..     ...         ...        ...            ...        ...            ...
# 494    YUM  131.419998  36.166136            N/A  11.559886            N/A
# 495    ZBH  130.759995  36.166136            N/A  11.559886            N/A
# 496   ZBRA  325.540009  36.166136            N/A  11.559886            N/A
# 497   ZION       53.34  36.166136            N/A  11.559886            N/A
# 498    ZTS  162.070007  36.166136            N/A  11.559886            N/A
#
#      P/Sales Ratio P/Sales Percentile  EV/EBITDA Ratio EV/EBITDA Percentile  \
# 0         6.810000                N/A        25.060000                  N/A
# 1         3.905054                N/A        13.017108                  N/A
# 2         0.870000                N/A        13.350000                  N/A
# 3         6.300000                N/A        19.210000                  N/A
# 4         4.450000                N/A        12.400000                  N/A
# ..             ...                ...              ...                  ...
# 494       3.905054                N/A        13.017108                  N/A
# 495       3.905054                N/A        13.017108                  N/A
# 496       3.905054                N/A        13.017108                  N/A
# 497       3.905054                N/A        13.017108                  N/A
# 498       3.905054                N/A        13.017108                  N/A
#
#      EV/Gross Ratio EV/Gross Percentile NumberSharesToBuy
# 0          6.970000                 N/A               N/A
# 1          4.541778                 N/A               N/A
# 2          1.140000                 N/A               N/A
# 3          6.320000                 N/A               N/A
# 4          5.430000                 N/A               N/A
# ..              ...                 ...               ...
# 494        4.541778                 N/A               N/A
# 495        4.541778                 N/A               N/A
# 496        4.541778                 N/A               N/A
# 497        4.541778                 N/A               N/A
# 498        4.541778                 N/A               N/A
#
# [499 rows x 13 columns]

# %% [markdown]
# ### Calculating Value Percentiles
#
# We now need to calculate value score percentiles for every stock in our universe. More specifically, we need to calculate percentile scores for the following metrics for every stock:
#
# - P/E
# - P/B
# - P/Sales
# - EV/EBITDA
# - EV/Gross
#
# Here's how we'll do this:

# %%
metrics = {
    "P/E Ratio" : "P/E Percentile",
    "P/B Ratio" : "P/B Percentile",
    "P/Sales Ratio" : "P/Sales Percentile",
    "EV/EBITDA Ratio" : "EV/EBITDA Percentile",
    "EV/Gross Ratio" : "EV/Gross Percentile"
}

for metric in metrics.keys():
    for row in value_df.index:
        value_df.loc[row, metrics[metric]] = stats.percentileofscore(value_df[metric], value_df.loc[row, metric])

value_df
# Out:
#     Ticker       Price  P/E Ratio P/E Percentile  P/B Ratio P/B Percentile  \
# 0        A  154.690002  37.190000      96.793587   8.680000      14.629259
# 1      AAL       16.91   2.810000       0.200401  11.559886      56.513026
# 2      AAP  149.059998  20.110000       6.813627   3.420000       8.617234
# 3     AAPL  151.759995  25.610000      10.621242  42.100000      99.599198
# 4     ABBV  144.550003  19.310000       6.012024  16.020000      98.396794
# ..     ...         ...        ...            ...        ...            ...
# 494    YUM  131.419998  36.166136      54.308617  11.559886      56.513026
# 495    ZBH  130.759995  36.166136      54.308617  11.559886      56.513026
# 496   ZBRA  325.540009  36.166136      54.308617  11.559886      56.513026
# 497   ZION       53.34  36.166136      54.308617  11.559886      56.513026
# 498    ZTS  162.070007  36.166136      54.308617  11.559886      56.513026
#
#      P/Sales Ratio P/Sales Percentile  EV/EBITDA Ratio EV/EBITDA Percentile  \
# 0         6.810000          97.194389        25.060000            96.993988
# 1         3.905054          51.603206        13.017108            47.995992
# 2         0.870000            2.60521        13.350000            90.380762
# 3         6.300000          96.993988        19.210000            94.589178
# 4         4.450000          93.787575        12.400000             5.410822
# ..             ...                ...              ...                  ...
# 494       3.905054          51.603206        13.017108            47.995992
# 495       3.905054          51.603206        13.017108            47.995992
# 496       3.905054          51.603206        13.017108            47.995992
# 497       3.905054          51.603206        13.017108            47.995992
# 498       3.905054          51.603206        13.017108            47.995992
#
#      EV/Gross Ratio EV/Gross Percentile NumberSharesToBuy
# 0          6.970000           96.993988               N/A
# 1          4.541778           51.503006               N/A
# 2          1.140000             2.50501               N/A
# 3          6.320000           96.593186               N/A
# 4          5.430000           93.587174               N/A
# ..              ...                 ...               ...
# 494        4.541778           51.503006               N/A
# 495        4.541778           51.503006               N/A
# 496        4.541778           51.503006               N/A
# 497        4.541778           51.503006               N/A
# 498        4.541778           51.503006               N/A
#
# [499 rows x 13 columns]

# %% [markdown]
# ### Calculating the RV Score
#
# We'll now calculate the RV score (which stands for Robust Value), which is the value score that we'll use to filter for stocks in our universe.
#
# The RV score will be the arithmetic mean of the 4 percentile scores that we calculated in the last section.
#
# To calculate the arithmetic mean, we will use the `mean` function from Python's built in stats module.

# %%
from statistics import mean

rv_score = []
for row in value_df.index:
    percentiles = []
    for metric in metrics.keys():
        percentiles.append(value_df.loc[row, metrics[metric]])
    
    ## now add the mean to the rv_score list
    rv_score.append(mean(percentiles))

value_df["RV Score"] = rv_score
value_df
# Out:
#     Ticker       Price  P/E Ratio P/E Percentile  P/B Ratio P/B Percentile  \
# 0        A  154.690002  37.190000      96.793587   8.680000      14.629259
# 1      AAL       16.91   2.810000       0.200401  11.559886      56.513026
# 2      AAP  149.059998  20.110000       6.813627   3.420000       8.617234
# 3     AAPL  151.759995  25.610000      10.621242  42.100000      99.599198
# 4     ABBV  144.550003  19.310000       6.012024  16.020000      98.396794
# ..     ...         ...        ...            ...        ...            ...
# 494    YUM  131.419998  36.166136      54.308617  11.559886      56.513026
# 495    ZBH  130.759995  36.166136      54.308617  11.559886      56.513026
# 496   ZBRA  325.540009  36.166136      54.308617  11.559886      56.513026
# 497   ZION       53.34  36.166136      54.308617  11.559886      56.513026
# 498    ZTS  162.070007  36.166136      54.308617  11.559886      56.513026
#
#      P/Sales Ratio P/Sales Percentile  EV/EBITDA Ratio EV/EBITDA Percentile  \
# 0         6.810000          97.194389        25.060000            96.993988
# 1         3.905054          51.603206        13.017108            47.995992
# 2         0.870000            2.60521        13.350000            90.380762
# 3         6.300000          96.993988        19.210000            94.589178
# 4         4.450000          93.787575        12.400000             5.410822
# ..             ...                ...              ...                  ...
# 494       3.905054          51.603206        13.017108            47.995992
# 495       3.905054          51.603206        13.017108            47.995992
# 496       3.905054          51.603206        13.017108            47.995992
# 497       3.905054          51.603206        13.017108            47.995992
# 498       3.905054          51.603206        13.017108            47.995992
#
#      EV/Gross Ratio EV/Gross Percentile NumberSharesToBuy   RV Score
# 0          6.970000           96.993988               N/A  80.521042
# 1          4.541778           51.503006               N/A  41.563126
# 2          1.140000             2.50501               N/A  22.184369
# 3          6.320000           96.593186               N/A  79.679359
# 4          5.430000           93.587174               N/A  59.438878
# ..              ...                 ...               ...        ...
# 494        4.541778           51.503006               N/A  52.384770
# 495        4.541778           51.503006               N/A  52.384770
# 496        4.541778           51.503006               N/A  52.384770
# 497        4.541778           51.503006               N/A  52.384770
# 498        4.541778           51.503006               N/A  52.384770
#
# [499 rows x 14 columns]

# %% [markdown]
# ### Selecting the 50 Best Value Stocks
#
# We can select the 50 best value stocks as we have done before:

# %%
value_df.sort_values("RV Score", ascending=True, inplace=True)
value_df_50 = value_df[:50]
value_df_50.reset_index(inplace=True, drop=True)

value_df_50
# Out:
#    Ticker       Price  P/E Ratio P/E Percentile   P/B Ratio P/B Percentile  \
# 0    DISH      13.975   4.960000       1.202405    0.470000       0.200401
# 1     DHI   97.364998   6.390000       1.402806    1.750000       3.106212
# 2     BWA   46.452999  14.010000       3.406814    1.670000       2.304609
# 3     ADM   81.660004  13.370000       3.006012    1.950000       4.408818
# 4     CNC   73.349998  21.970000       8.817635    1.680000        2.60521
# 5    CTRA       24.16   4.490000       0.801603    1.540000       1.803607
# 6     COP  111.099998   7.640000       2.004008    2.840000        7.41483
# 7     BBY   86.684998  13.420000       3.206413    6.630000      12.825651
# 8     CZR   53.549999  16.590000        5.01002    3.000000       7.815631
# 9     BEN   31.450001  16.330000       4.609218    1.370000       1.002004
# 10   CARR   45.005001  11.360000        2.60521    5.510000      12.024048
# 11     DD   76.985001  23.510000       9.819639    1.490000       1.302605
# 12    CPB   50.900002  19.080000       5.811623    4.350000       9.819639
# 13    CNP      29.055  20.830000        7.61523    2.040000       5.210421
# 14    BMY   73.485001  24.670000      10.220441    4.490000       10.02004
# 15    AIG       60.73   3.630000       0.400802    1.170000       0.601202
# 16    AIZ  131.005005  21.640000       8.216433    1.700000       2.805611
# 17    AFL      70.625  10.460000       2.204409    1.900000       3.807615
# 18   BBWI   44.189999  12.510000       2.805611   11.559886      56.513026
# 19    BAX   45.599998  36.166136      54.308617    4.280000       9.619238
# 20   ACGL   64.074997  19.660000       6.613226    2.070000       5.410822
# 21    AMP  352.339996  15.470000       4.008016   10.130000       15.03006
# 22    COF  117.870003   6.800000       1.603206    0.880000       0.400802
# 23    APA       41.91   4.010000       0.601202   22.700000      98.797595
# 24    ALL  136.830002  36.166136      54.308617    1.920000       4.008016
# 25    AAP  149.059998  20.110000       6.813627    3.420000       8.617234
# 26    ABC  157.729996  19.540000       6.212425  442.780000          100.0
# 27    BAC   36.459999  11.330000        2.40481    1.180000       0.801603
# 28    DFS  116.010002   7.470000       1.803607    2.120000       6.012024
# 29   AMCR        11.3  22.060000       9.018036    4.640000      10.220441
# 30    AEP   90.139999  19.640000       6.412826    2.000000       4.709419
# 31    CAG   36.299999  26.180000      11.222445    2.030000        5.01002
# 32   BIIB  286.279999  14.900000       3.807615    3.290000       8.216433
# 33   CTLT   71.029999  23.290000       9.619238    2.100000       5.711423
# 34    AVY  183.860001  20.290000       7.014028    7.780000      13.827655
# 35  BRK-B  308.410004  36.166136      54.308617    1.500000       1.603206
# 36   CSCO      46.945  17.810000       5.210421    5.030000      11.022044
# 37     BA  212.164993  36.166136      54.308617   11.559886      56.513026
# 38    AEE   84.650002  21.740000       8.617234    2.200000       6.412826
# 39    AXP  178.664993  18.160000       5.410822    5.320000      11.623246
# 40     DG  227.660004  22.500000       9.418838    8.490000      14.428858
# 41     DE  408.740906  18.340000       5.611222    6.260000      12.625251
# 42    ACN  284.170013  25.760000      10.821643    7.770000      13.627255
# 43    CRL  259.549988  29.200000      12.224449    4.810000      10.420842
# 44    BKR   32.485001  36.166136      54.308617   11.559886      56.513026
# 45    AZO      2430.0  20.540000        7.41483   11.559886      56.513026
# 46    AES   26.014999  36.166136      54.308617    6.890000      13.226453
# 47    CVS      89.555  36.360000      96.192385    1.600000       2.004008
# 48    BXP   72.830002  14.510000       3.607214    2.000000       4.709419
# 49   CTVA   61.845001  37.350000      96.993988    1.750000       3.106212
#
#     P/Sales Ratio P/Sales Percentile  EV/EBITDA Ratio EV/EBITDA Percentile  \
# 0        0.560000           1.402806         9.110000              2.40481
# 1        1.070000           2.805611         5.200000             1.402806
# 2        0.750000           2.204409         7.320000             1.603206
# 3        0.510000           1.202405        10.240000             3.406814
# 4        0.310000           0.601202         9.730000             3.006012
# 5        2.220000           6.813627         3.140000             1.002004
# 6        1.810000           5.210421         3.900000             1.202405
# 7        0.430000           1.002004         7.880000             1.803607
# 8        1.080000           3.006012         9.520000             2.805611
# 9        1.950000           5.811623        12.650000             6.012024
# 10       2.010000           6.012024         9.240000              2.60521
# 11       2.200000           6.613226        11.730000             4.609218
# 12       1.710000           4.809619        12.620000             5.811623
# 13       2.120000           6.412826        10.940000             4.008016
# 14       3.380000          10.621242        10.020000             3.206413
# 15       0.840000            2.40481        13.017108            47.995992
# 16       0.730000           2.004008        13.017108            47.995992
# 17       2.250000           7.214429        13.017108            47.995992
# 18       1.470000           4.208417         9.060000             2.204409
# 19       1.610000           4.609218       -63.700000             0.400802
# 20       2.610000           8.617234        13.017108            47.995992
# 21       2.770000           9.018036        13.017108            47.995992
# 22       1.400000           3.607214        13.017108            47.995992
# 23       1.340000           3.406814         2.670000             0.801603
# 24       0.680000           1.603206        13.017108            47.995992
# 25       0.870000            2.60521        13.350000            90.380762
# 26       0.140000           0.400802        11.700000             4.408818
# 27       3.110000           10.02004        13.017108            47.995992
# 28       2.410000            7.41483        13.017108            47.995992
# 29       1.240000           3.206413        13.050000            89.779559
# 30       2.570000           8.316633        11.870000             4.809619
# 31       1.480000           4.408818        17.540000            93.186373
# 32       4.120000          93.587174        10.450000             3.607214
# 33       2.040000           6.212425        13.660000            90.581162
# 34       1.720000            5.01002        13.110000            90.180361
# 35       2.710000           8.817635        13.017108            47.995992
# 36       3.920000           92.58517        11.620000             4.208417
# 37       1.870000           5.611222      -324.100000             0.200401
# 38       3.010000           9.819639        12.190000             5.210421
# 39       2.540000           8.016032        13.017108            47.995992
# 40       1.460000           4.008016        17.430000            92.985972
# 41       2.520000           7.815631        16.160000            91.983968
# 42       2.920000           9.318637        17.700000            93.386774
# 43       3.370000          10.420842        18.800000            93.987976
# 44       3.905054          51.603206         8.780000             2.004008
# 45       2.990000           9.619238        14.880000            91.382766
# 46       1.450000           3.807615        29.460000            97.795591
# 47       0.360000           0.801603        15.290000            91.583166
# 48       3.960000          92.785571        11.910000              5.01002
# 49       2.570000           8.316633        15.480000            91.783567
#
#     EV/Gross Ratio EV/Gross Percentile NumberSharesToBuy   RV Score
# 0         1.720000            3.206413               N/A   1.683367
# 1         1.140000             2.50501               N/A   2.244489
# 2         0.940000            2.004008               N/A   2.304609
# 3         0.630000            1.202405               N/A   2.645291
# 4         0.330000            0.601202               N/A   3.126253
# 5         2.380000            5.711423               N/A   3.226453
# 6         1.830000            3.607214               N/A   3.887776
# 7         0.480000            0.801603               N/A   3.927856
# 8         2.220000            4.809619               N/A   4.689379
# 9         2.810000            7.014028               N/A   4.889780
# 10        2.240000            5.210421               N/A   5.691383
# 11        2.730000            6.813627               N/A   5.831663
# 12        2.230000             5.01002               N/A   6.252505
# 13        3.870000            9.218437               N/A   6.492986
# 14        4.030000            9.418838               N/A   8.697395
# 15        1.250000            2.805611               N/A  10.841683
# 16        0.770000            1.402806               N/A  12.484970
# 17        2.320000            5.410822               N/A  13.326653
# 18        2.150000            4.408818               N/A  14.028056
# 19        2.640000            6.613226               N/A  15.110220
# 20        2.860000             7.41483               N/A  15.210421
# 21        2.450000            6.212425               N/A  16.452906
# 22        4.541778           51.503006               N/A  21.022044
# 23        1.740000            3.406814               N/A  21.402806
# 24        0.800000            1.603206               N/A  21.903808
# 25        1.140000             2.50501               N/A  22.184369
# 26        0.150000            0.400802               N/A  22.284569
# 27        4.541778           51.503006               N/A  22.545090
# 28        4.541778           51.503006               N/A  22.945892
# 29        1.690000            3.006012               N/A  23.046092
# 30        4.590000            92.58517               N/A  23.366733
# 31        2.210000            4.609218               N/A  23.687375
# 32        4.220000           10.220441               N/A  23.887776
# 33        2.920000             7.61523               N/A  23.947896
# 34        2.030000            4.008016               N/A  24.008016
# 35        3.060000            8.216433               N/A  24.188377
# 36        3.670000            9.018036               N/A  24.408818
# 37        2.480000            6.412826               N/A  24.609218
# 38        5.010000           93.386774               N/A  24.689379
# 39        4.541778           51.503006               N/A  24.909820
# 40        1.870000            3.807615               N/A  24.929860
# 41        3.350000            8.817635               N/A  25.370741
# 42        2.930000            7.815631               N/A  26.993988
# 43        4.330000           10.420842               N/A  27.494990
# 44        0.970000            2.204409               N/A  33.326653
# 45        3.320000            8.617234               N/A  34.709419
# 46        3.130000            8.416834               N/A  35.511022
# 47        0.520000            1.002004               N/A  38.316633
# 48        8.460000           97.795591               N/A  40.781563
# 49        2.420000            6.012024               N/A  41.242485

# %% [markdown]
# ### Caluulating the Number of Shares to Buy
#
# We can use our prebuilt functions:

# %%
portfolio_size = portfolio_size_input()

number_shares_to_buy(portfolio_size, value_df_50)

value_df_50
# Out:
#    Ticker       Price  P/E Ratio P/E Percentile   P/B Ratio P/B Percentile  \
# 0    DISH      13.975   4.960000       1.202405    0.470000       0.200401
# 1     DHI   97.364998   6.390000       1.402806    1.750000       3.106212
# 2     BWA   46.452999  14.010000       3.406814    1.670000       2.304609
# 3     ADM   81.660004  13.370000       3.006012    1.950000       4.408818
# 4     CNC   73.349998  21.970000       8.817635    1.680000        2.60521
# 5    CTRA       24.16   4.490000       0.801603    1.540000       1.803607
# 6     COP  111.099998   7.640000       2.004008    2.840000        7.41483
# 7     BBY   86.684998  13.420000       3.206413    6.630000      12.825651
# 8     CZR   53.549999  16.590000        5.01002    3.000000       7.815631
# 9     BEN   31.450001  16.330000       4.609218    1.370000       1.002004
# 10   CARR   45.005001  11.360000        2.60521    5.510000      12.024048
# 11     DD   76.985001  23.510000       9.819639    1.490000       1.302605
# 12    CPB   50.900002  19.080000       5.811623    4.350000       9.819639
# 13    CNP      29.055  20.830000        7.61523    2.040000       5.210421
# 14    BMY   73.485001  24.670000      10.220441    4.490000       10.02004
# 15    AIG       60.73   3.630000       0.400802    1.170000       0.601202
# 16    AIZ  131.005005  21.640000       8.216433    1.700000       2.805611
# 17    AFL      70.625  10.460000       2.204409    1.900000       3.807615
# 18   BBWI   44.189999  12.510000       2.805611   11.559886      56.513026
# 19    BAX   45.599998  36.166136      54.308617    4.280000       9.619238
# 20   ACGL   64.074997  19.660000       6.613226    2.070000       5.410822
# 21    AMP  352.339996  15.470000       4.008016   10.130000       15.03006
# 22    COF  117.870003   6.800000       1.603206    0.880000       0.400802
# 23    APA       41.91   4.010000       0.601202   22.700000      98.797595
# 24    ALL  136.830002  36.166136      54.308617    1.920000       4.008016
# 25    AAP  149.059998  20.110000       6.813627    3.420000       8.617234
# 26    ABC  157.729996  19.540000       6.212425  442.780000          100.0
# 27    BAC   36.459999  11.330000        2.40481    1.180000       0.801603
# 28    DFS  116.010002   7.470000       1.803607    2.120000       6.012024
# 29   AMCR        11.3  22.060000       9.018036    4.640000      10.220441
# 30    AEP   90.139999  19.640000       6.412826    2.000000       4.709419
# 31    CAG   36.299999  26.180000      11.222445    2.030000        5.01002
# 32   BIIB  286.279999  14.900000       3.807615    3.290000       8.216433
# 33   CTLT   71.029999  23.290000       9.619238    2.100000       5.711423
# 34    AVY  183.860001  20.290000       7.014028    7.780000      13.827655
# 35  BRK-B  308.410004  36.166136      54.308617    1.500000       1.603206
# 36   CSCO      46.945  17.810000       5.210421    5.030000      11.022044
# 37     BA  212.164993  36.166136      54.308617   11.559886      56.513026
# 38    AEE   84.650002  21.740000       8.617234    2.200000       6.412826
# 39    AXP  178.664993  18.160000       5.410822    5.320000      11.623246
# 40     DG  227.660004  22.500000       9.418838    8.490000      14.428858
# 41     DE  408.740906  18.340000       5.611222    6.260000      12.625251
# 42    ACN  284.170013  25.760000      10.821643    7.770000      13.627255
# 43    CRL  259.549988  29.200000      12.224449    4.810000      10.420842
# 44    BKR   32.485001  36.166136      54.308617   11.559886      56.513026
# 45    AZO      2430.0  20.540000        7.41483   11.559886      56.513026
# 46    AES   26.014999  36.166136      54.308617    6.890000      13.226453
# 47    CVS      89.555  36.360000      96.192385    1.600000       2.004008
# 48    BXP   72.830002  14.510000       3.607214    2.000000       4.709419
# 49   CTVA   61.845001  37.350000      96.993988    1.750000       3.106212
#
#     P/Sales Ratio P/Sales Percentile  EV/EBITDA Ratio EV/EBITDA Percentile  \
# 0        0.560000           1.402806         9.110000              2.40481
# 1        1.070000           2.805611         5.200000             1.402806
# 2        0.750000           2.204409         7.320000             1.603206
# 3        0.510000           1.202405        10.240000             3.406814
# 4        0.310000           0.601202         9.730000             3.006012
# 5        2.220000           6.813627         3.140000             1.002004
# 6        1.810000           5.210421         3.900000             1.202405
# 7        0.430000           1.002004         7.880000             1.803607
# 8        1.080000           3.006012         9.520000             2.805611
# 9        1.950000           5.811623        12.650000             6.012024
# 10       2.010000           6.012024         9.240000              2.60521
# 11       2.200000           6.613226        11.730000             4.609218
# 12       1.710000           4.809619        12.620000             5.811623
# 13       2.120000           6.412826        10.940000             4.008016
# 14       3.380000          10.621242        10.020000             3.206413
# 15       0.840000            2.40481        13.017108            47.995992
# 16       0.730000           2.004008        13.017108            47.995992
# 17       2.250000           7.214429        13.017108            47.995992
# 18       1.470000           4.208417         9.060000             2.204409
# 19       1.610000           4.609218       -63.700000             0.400802
# 20       2.610000           8.617234        13.017108            47.995992
# 21       2.770000           9.018036        13.017108            47.995992
# 22       1.400000           3.607214        13.017108            47.995992
# 23       1.340000           3.406814         2.670000             0.801603
# 24       0.680000           1.603206        13.017108            47.995992
# 25       0.870000            2.60521        13.350000            90.380762
# 26       0.140000           0.400802        11.700000             4.408818
# 27       3.110000           10.02004        13.017108            47.995992
# 28       2.410000            7.41483        13.017108            47.995992
# 29       1.240000           3.206413        13.050000            89.779559
# 30       2.570000           8.316633        11.870000             4.809619
# 31       1.480000           4.408818        17.540000            93.186373
# 32       4.120000          93.587174        10.450000             3.607214
# 33       2.040000           6.212425        13.660000            90.581162
# 34       1.720000            5.01002        13.110000            90.180361
# 35       2.710000           8.817635        13.017108            47.995992
# 36       3.920000           92.58517        11.620000             4.208417
# 37       1.870000           5.611222      -324.100000             0.200401
# 38       3.010000           9.819639        12.190000             5.210421
# 39       2.540000           8.016032        13.017108            47.995992
# 40       1.460000           4.008016        17.430000            92.985972
# 41       2.520000           7.815631        16.160000            91.983968
# 42       2.920000           9.318637        17.700000            93.386774
# 43       3.370000          10.420842        18.800000            93.987976
# 44       3.905054          51.603206         8.780000             2.004008
# 45       2.990000           9.619238        14.880000            91.382766
# 46       1.450000           3.807615        29.460000            97.795591
# 47       0.360000           0.801603        15.290000            91.583166
# 48       3.960000          92.785571        11.910000              5.01002
# 49       2.570000           8.316633        15.480000            91.783567
#
#     EV/Gross Ratio EV/Gross Percentile NumberSharesToBuy   RV Score
# 0         1.720000            3.206413              1431   1.683367
# 1         1.140000             2.50501               205   2.244489
# 2         0.940000            2.004008               430   2.304609
# 3         0.630000            1.202405               244   2.645291
# 4         0.330000            0.601202               272   3.126253
# 5         2.380000            5.711423               827   3.226453
# 6         1.830000            3.607214               180   3.887776
# 7         0.480000            0.801603               230   3.927856
# 8         2.220000            4.809619               373   4.689379
# 9         2.810000            7.014028               635   4.889780
# 10        2.240000            5.210421               444   5.691383
# 11        2.730000            6.813627               259   5.831663
# 12        2.230000             5.01002               392   6.252505
# 13        3.870000            9.218437               688   6.492986
# 14        4.030000            9.418838               272   8.697395
# 15        1.250000            2.805611               329  10.841683
# 16        0.770000            1.402806               152  12.484970
# 17        2.320000            5.410822               283  13.326653
# 18        2.150000            4.408818               452  14.028056
# 19        2.640000            6.613226               438  15.110220
# 20        2.860000             7.41483               312  15.210421
# 21        2.450000            6.212425                56  16.452906
# 22        4.541778           51.503006               169  21.022044
# 23        1.740000            3.406814               477  21.402806
# 24        0.800000            1.603206               146  21.903808
# 25        1.140000             2.50501               134  22.184369
# 26        0.150000            0.400802               126  22.284569
# 27        4.541778           51.503006               548  22.545090
# 28        4.541778           51.503006               172  22.945892
# 29        1.690000            3.006012              1769  23.046092
# 30        4.590000            92.58517               221  23.366733
# 31        2.210000            4.609218               550  23.687375
# 32        4.220000           10.220441                69  23.887776
# 33        2.920000             7.61523               281  23.947896
# 34        2.030000            4.008016               108  24.008016
# 35        3.060000            8.216433                64  24.188377
# 36        3.670000            9.018036               426  24.408818
# 37        2.480000            6.412826                94  24.609218
# 38        5.010000           93.386774               236  24.689379
# 39        4.541778           51.503006               111  24.909820
# 40        1.870000            3.807615                87  24.929860
# 41        3.350000            8.817635                48  25.370741
# 42        2.930000            7.815631                70  26.993988
# 43        4.330000           10.420842                77  27.494990
# 44        0.970000            2.204409               615  33.326653
# 45        3.320000            8.617234                 8  34.709419
# 46        3.130000            8.416834               768  35.511022
# 47        0.520000            1.002004               223  38.316633
# 48        8.460000           97.795591               274  40.781563
# 49        2.420000            6.012024               323  41.242485
