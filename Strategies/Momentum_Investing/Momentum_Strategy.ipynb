# %% [markdown]
# # Momentum Investing Strategy #
#
# _Momentum Investing_ means investing in stocks that have increased in prices the most.
#
# For this project, we're going to build an investing strategy that selects the 50 stocks with the highest price momentum, From there, we will calculate recommended trades for an equal-weight portfolio of these 50 stocks.
#
# ## Library Imports ##

# %%
import numpy as np
import pandas as pd

import requests
import math

from scipy.stats import percentileofscore as score
import xlsxwriter
import yfinance as yf

from secrets import ALPHAVANTAGE_API_KEY



## Can import datafile if don't want to run the whole thing
# final_dataframe = pd.read_csv("OneYearPriceReturn.csv", index_col=0)
# hqm_df = pd.read_csv("HQM.csv", index_col=0)

# %% [markdown]
# ## Importing List of Stocks ##
#
# As before, we'll need to import our list of stocks.

# %%
tickers = pd.read_csv("constituents.csv")
tickers = tickers.loc[:,"Symbol"]
tickers
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4      ABMD
#        ...
# 500     YUM
# 501    ZBRA
# 502     ZBH
# 503    ZION
# 504     ZTS
# Name: Symbol, Length: 505, dtype: object

# %% [markdown]
# ***
# ## Getting Market Data ##
#
# For this project we will be pulling price and also one-year stock returns. For this, we need to calculate the Rate of Return (RoR) which is given by `(Year End Price - Year Start Price)/Year Start Price`.

# %%
## THIS CELL TAKES APPROX 5 MINS TO RUN

my_columns = ["Ticker", "Price", "One-YearPriceReturn", "NumberSharesToBuy"]
final_dataframe = pd.DataFrame(columns=my_columns)
i = 0
n = len(tickers)

for tick in tickers:
    ## Timer if wanted
    # i += 1
    # p = np.round((100*i)/n)
    # print(f"{p}% completed,", tick)
    try:
        stock = yf.Ticker(tick)
        data = stock.history(period="1y")
        start_price = data.Close[0]
        end_price = data.Close[-1]
        one_year_return = (end_price - start_price)/start_price
        row = pd.Series([tick, end_price, one_year_return, 'N/A'], index = my_columns)
        final_dataframe = pd.concat([final_dataframe, row.to_frame().T], ignore_index=True)
    except:
        print("Error with: ", tick)

final_dataframe.to_csv("OneYearPriceReturn.csv")
# Out:
# 0.0% completed, MMM
# 0.0% completed, AOS
# 1.0% completed, ABT
# 1.0% completed, ABBV
# 1.0% completed, ABMD
# 1.0% completed, ACN
# 1.0% completed, ATVI
# 2.0% completed, ADM
# 2.0% completed, ADBE
# 2.0% completed, AAP
# 2.0% completed, AMD
# 2.0% completed, AES
# 3.0% completed, AFL
# 3.0% completed, A
# 3.0% completed, APD
# 3.0% completed, AKAM
# 3.0% completed, ALK
# 4.0% completed, ALB
# 4.0% completed, ARE
# 4.0% completed, ALGN
# 4.0% completed, ALLE
# 4.0% completed, LNT
# 5.0% completed, ALL
# 5.0% completed, GOOGL
# 5.0% completed, GOOG
# 5.0% completed, MO
# 5.0% completed, AMZN
# 6.0% completed, AMCR
# 6.0% completed, AEE
# 6.0% completed, AAL
# 6.0% completed, AEP
# 6.0% completed, AXP
# 7.0% completed, AIG
# 7.0% completed, AMT
# 7.0% completed, AWK
# 7.0% completed, AMP
# 7.0% completed, ABC
# 8.0% completed, AME
# 8.0% completed, AMGN
# 8.0% completed, APH
# 8.0% completed, ADI
# 8.0% completed, ANSS
# 9.0% completed, ANTM
# - ANTM: No data found, symbol may be delisted
# Error with:  ANTM
# 9.0% completed, AON
# 9.0% completed, APA
# 9.0% completed, AAPL
# 9.0% completed, AMAT
# 10.0% completed, APTV
# 10.0% completed, ANET
# 10.0% completed, AJG
# 10.0% completed, AIZ
# 10.0% completed, T
# 10.0% completed, ATO
# 11.0% completed, ADSK
# 11.0% completed, ADP
# 11.0% completed, AZO
# 11.0% completed, AVB
# 11.0% completed, AVY
# 12.0% completed, BKR
# 12.0% completed, BLL
# - BLL: No data found, symbol may be delisted
# Error with:  BLL
# 12.0% completed, BAC
# 12.0% completed, BBWI
# 12.0% completed, BAX
# 13.0% completed, BDX
# 13.0% completed, BRK.B
# - BRK.B: No data found, symbol may be delisted
# Error with:  BRK.B
# 13.0% completed, BBY
# 13.0% completed, BIO
# 13.0% completed, TECH
# 14.0% completed, BIIB
# 14.0% completed, BLK
# 14.0% completed, BK
# 14.0% completed, BA
# 14.0% completed, BKNG
# 15.0% completed, BWA
# 15.0% completed, BXP
# 15.0% completed, BSX
# 15.0% completed, BMY
# 15.0% completed, AVGO
# 16.0% completed, BR
# 16.0% completed, BRO
# 16.0% completed, BF.B
# - BF.B: No data found for this date range, symbol may be delisted
# Error with:  BF.B
# 16.0% completed, CHRW
# 16.0% completed, CDNS
# 17.0% completed, CZR
# 17.0% completed, CPB
# 17.0% completed, COF
# 17.0% completed, CAH
# 17.0% completed, KMX
# 18.0% completed, CCL
# 18.0% completed, CARR
# 18.0% completed, CTLT
# 18.0% completed, CAT
# 18.0% completed, CBOE
# 19.0% completed, CBRE
# 19.0% completed, CDW
# 19.0% completed, CE
# 19.0% completed, CNC
# 19.0% completed, CNP
# 20.0% completed, CDAY
# 20.0% completed, CERN
# - CERN: No data found, symbol may be delisted
# Error with:  CERN
# 20.0% completed, CF
# 20.0% completed, CRL
# 20.0% completed, SCHW
# 21.0% completed, CHTR
# 21.0% completed, CVX
# 21.0% completed, CMG
# 21.0% completed, CB
# 21.0% completed, CHD
# 22.0% completed, CI
# 22.0% completed, CINF
# 22.0% completed, CTAS
# 22.0% completed, CSCO
# 22.0% completed, C
# 23.0% completed, CFG
# 23.0% completed, CTXS
# - CTXS: No data found, symbol may be delisted
# Error with:  CTXS
# 23.0% completed, CLX
# 23.0% completed, CME
# 23.0% completed, CMS
# 24.0% completed, KO
# 24.0% completed, CTSH
# 24.0% completed, CL
# 24.0% completed, CMCSA
# 24.0% completed, CMA
# 25.0% completed, CAG
# 25.0% completed, COP
# 25.0% completed, ED
# 25.0% completed, STZ
# 25.0% completed, CPRT
# 26.0% completed, GLW
# 26.0% completed, CTVA
# 26.0% completed, COST
# 26.0% completed, CTRA
# 26.0% completed, CCI
# 27.0% completed, CSX
# 27.0% completed, CMI
# 27.0% completed, CVS
# 27.0% completed, DHI
# 27.0% completed, DHR
# 28.0% completed, DRI
# 28.0% completed, DVA
# 28.0% completed, DE
# 28.0% completed, DAL
# 28.0% completed, XRAY
# 29.0% completed, DVN
# 29.0% completed, DXCM
# 29.0% completed, FANG
# 29.0% completed, DLR
# 29.0% completed, DFS
# 30.0% completed, DISCA
# - DISCA: No data found, symbol may be delisted
# Error with:  DISCA
# 30.0% completed, DISCK
# - DISCK: No data found, symbol may be delisted
# Error with:  DISCK
# 30.0% completed, DISH
# 30.0% completed, DG
# 30.0% completed, DLTR
# 30.0% completed, D
# 31.0% completed, DPZ
# 31.0% completed, DOV
# 31.0% completed, DOW
# 31.0% completed, DTE
# 31.0% completed, DUK
# 32.0% completed, DRE
# - DRE: No data found, symbol may be delisted
# Error with:  DRE
# 32.0% completed, DD
# 32.0% completed, DXC
# 32.0% completed, EMN
# 32.0% completed, ETN
# 33.0% completed, EBAY
# 33.0% completed, ECL
# 33.0% completed, EIX
# 33.0% completed, EW
# 33.0% completed, EA
# 34.0% completed, LLY
# 34.0% completed, EMR
# 34.0% completed, ENPH
# 34.0% completed, ETR
# 34.0% completed, EOG
# 35.0% completed, EFX
# 35.0% completed, EQIX
# 35.0% completed, EQR
# 35.0% completed, ESS
# 35.0% completed, EL
# 36.0% completed, ETSY
# 36.0% completed, RE
# 36.0% completed, EVRG
# 36.0% completed, ES
# 36.0% completed, EXC
# 37.0% completed, EXPE
# 37.0% completed, EXPD
# 37.0% completed, EXR
# 37.0% completed, XOM
# 37.0% completed, FFIV
# 38.0% completed, FB
# - FB: No data found, symbol may be delisted
# Error with:  FB
# 38.0% completed, FAST
# 38.0% completed, FRT
# 38.0% completed, FDX
# 38.0% completed, FIS
# 39.0% completed, FITB
# 39.0% completed, FRC
# 39.0% completed, FE
# 39.0% completed, FISV
# 39.0% completed, FLT
# 40.0% completed, FMC
# 40.0% completed, F
# 40.0% completed, FTNT
# 40.0% completed, FTV
# 40.0% completed, FBHS
# 41.0% completed, FOXA
# 41.0% completed, FOX
# 41.0% completed, BEN
# 41.0% completed, FCX
# 41.0% completed, GPS
# 42.0% completed, GRMN
# 42.0% completed, IT
# 42.0% completed, GNRC
# 42.0% completed, GD
# 42.0% completed, GE
# 43.0% completed, GIS
# 43.0% completed, GM
# 43.0% completed, GPC
# 43.0% completed, GILD
# 43.0% completed, GPN
# 44.0% completed, GL
# 44.0% completed, GS
# 44.0% completed, HAL
# 44.0% completed, HBI
# 44.0% completed, HAS
# 45.0% completed, HCA
# 45.0% completed, PEAK
# 45.0% completed, HSIC
# 45.0% completed, HES
# 45.0% completed, HPE
# 46.0% completed, HLT
# 46.0% completed, HOLX
# 46.0% completed, HD
# 46.0% completed, HON
# 46.0% completed, HRL
# 47.0% completed, HST
# 47.0% completed, HWM
# 47.0% completed, HPQ
# 47.0% completed, HUM
# 47.0% completed, HBAN
# 48.0% completed, HII
# 48.0% completed, IBM
# 48.0% completed, IEX
# 48.0% completed, IDXX
# 48.0% completed, INFO
# - INFO: No data found, symbol may be delisted
# Error with:  INFO
# 49.0% completed, ITW
# 49.0% completed, ILMN
# 49.0% completed, INCY
# 49.0% completed, IR
# 49.0% completed, INTC
# 50.0% completed, ICE
# 50.0% completed, IFF
# 50.0% completed, IP
# 50.0% completed, IPG
# 50.0% completed, INTU
# 50.0% completed, ISRG
# 51.0% completed, IVZ
# 51.0% completed, IPGP
# 51.0% completed, IQV
# 51.0% completed, IRM
# 51.0% completed, JBHT
# 52.0% completed, JKHY
# 52.0% completed, J
# 52.0% completed, SJM
# 52.0% completed, JNJ
# 52.0% completed, JCI
# 53.0% completed, JPM
# 53.0% completed, JNPR
# 53.0% completed, KSU
# - KSU: No data found, symbol may be delisted
# Error with:  KSU
# 53.0% completed, K
# 53.0% completed, KEY
# 54.0% completed, KEYS
# 54.0% completed, KMB
# 54.0% completed, KIM
# 54.0% completed, KMI
# 54.0% completed, KLAC
# 55.0% completed, KHC
# 55.0% completed, KR
# 55.0% completed, LHX
# 55.0% completed, LH
# 55.0% completed, LRCX
# 56.0% completed, LW
# 56.0% completed, LVS
# 56.0% completed, LEG
# 56.0% completed, LDOS
# 56.0% completed, LEN
# 57.0% completed, LNC
# 57.0% completed, LIN
# 57.0% completed, LYV
# 57.0% completed, LKQ
# 57.0% completed, LMT
# 58.0% completed, L
# 58.0% completed, LOW
# 58.0% completed, LUMN
# 58.0% completed, LYB
# 58.0% completed, MTB
# 59.0% completed, MRO
# 59.0% completed, MPC
# 59.0% completed, MKTX
# 59.0% completed, MAR
# 59.0% completed, MMC
# 60.0% completed, MLM
# 60.0% completed, MAS
# 60.0% completed, MA
# 60.0% completed, MTCH
# 60.0% completed, MKC
# 61.0% completed, MCD
# 61.0% completed, MCK
# 61.0% completed, MDT
# 61.0% completed, MRK
# 61.0% completed, MET
# 62.0% completed, MTD
# 62.0% completed, MGM
# 62.0% completed, MCHP
# 62.0% completed, MU
# 62.0% completed, MSFT
# 63.0% completed, MAA
# 63.0% completed, MRNA
# 63.0% completed, MHK
# 63.0% completed, TAP
# 63.0% completed, MDLZ
# 64.0% completed, MPWR
# 64.0% completed, MNST
# 64.0% completed, MCO
# 64.0% completed, MS
# 64.0% completed, MSI
# 65.0% completed, MSCI
# 65.0% completed, NDAQ
# 65.0% completed, NTAP
# 65.0% completed, NFLX
# 65.0% completed, NWL
# 66.0% completed, NEM
# 66.0% completed, NWSA
# 66.0% completed, NWS
# 66.0% completed, NEE
# 66.0% completed, NLSN
# - NLSN: No data found, symbol may be delisted
# Error with:  NLSN
# 67.0% completed, NKE
# 67.0% completed, NI
# 67.0% completed, NSC
# 67.0% completed, NTRS
# 67.0% completed, NOC
# 68.0% completed, NLOK
# - NLOK: No data found, symbol may be delisted
# Error with:  NLOK
# 68.0% completed, NCLH
# 68.0% completed, NRG
# 68.0% completed, NUE
# 68.0% completed, NVDA
# 69.0% completed, NVR
# 69.0% completed, NXPI
# 69.0% completed, ORLY
# 69.0% completed, OXY
# 69.0% completed, ODFL
# 70.0% completed, OMC
# 70.0% completed, OKE
# 70.0% completed, ORCL
# 70.0% completed, OGN
# 70.0% completed, OTIS
# 70.0% completed, PCAR
# 71.0% completed, PKG
# 71.0% completed, PH
# 71.0% completed, PAYX
# 71.0% completed, PAYC
# 71.0% completed, PYPL
# 72.0% completed, PENN
# 72.0% completed, PNR
# 72.0% completed, PBCT
# - PBCT: No data found, symbol may be delisted
# Error with:  PBCT
# 72.0% completed, PEP
# 72.0% completed, PKI
# 73.0% completed, PFE
# 73.0% completed, PM
# 73.0% completed, PSX
# 73.0% completed, PNW
# 73.0% completed, PXD
# 74.0% completed, PNC
# 74.0% completed, POOL
# 74.0% completed, PPG
# 74.0% completed, PPL
# 74.0% completed, PFG
# 75.0% completed, PG
# 75.0% completed, PGR
# 75.0% completed, PLD
# 75.0% completed, PRU
# 75.0% completed, PTC
# 76.0% completed, PEG
# 76.0% completed, PSA
# 76.0% completed, PHM
# 76.0% completed, PVH
# 76.0% completed, QRVO
# 77.0% completed, QCOM
# 77.0% completed, PWR
# 77.0% completed, DGX
# 77.0% completed, RL
# 77.0% completed, RJF
# 78.0% completed, RTX
# 78.0% completed, O
# 78.0% completed, REG
# 78.0% completed, REGN
# 78.0% completed, RF
# 79.0% completed, RSG
# 79.0% completed, RMD
# 79.0% completed, RHI
# 79.0% completed, ROK
# 79.0% completed, ROL
# 80.0% completed, ROP
# 80.0% completed, ROST
# 80.0% completed, RCL
# 80.0% completed, SPGI
# 80.0% completed, CRM
# 81.0% completed, SBAC
# 81.0% completed, SLB
# 81.0% completed, STX
# 81.0% completed, SEE
# 81.0% completed, SRE
# 82.0% completed, NOW
# 82.0% completed, SHW
# 82.0% completed, SPG
# 82.0% completed, SWKS
# 82.0% completed, SNA
# 83.0% completed, SO
# 83.0% completed, LUV
# 83.0% completed, SWK
# 83.0% completed, SBUX
# 83.0% completed, STT
# 84.0% completed, STE
# 84.0% completed, SYK
# 84.0% completed, SIVB
# 84.0% completed, SYF
# 84.0% completed, SNPS
# 85.0% completed, SYY
# 85.0% completed, TMUS
# 85.0% completed, TROW
# 85.0% completed, TTWO
# 85.0% completed, TPR
# 86.0% completed, TGT
# 86.0% completed, TEL
# 86.0% completed, TDY
# 86.0% completed, TFX
# 86.0% completed, TER
# 87.0% completed, TSLA
# 87.0% completed, TXN
# 87.0% completed, TXT
# 87.0% completed, COO
# 87.0% completed, HIG
# 88.0% completed, HSY
# 88.0% completed, MOS
# 88.0% completed, TRV
# 88.0% completed, DIS
# 88.0% completed, TMO
# 89.0% completed, TJX
# 89.0% completed, TSCO
# 89.0% completed, TT
# 89.0% completed, TDG
# 89.0% completed, TRMB
# 90.0% completed, TFC
# 90.0% completed, TWTR
# 90.0% completed, TYL
# 90.0% completed, TSN
# 90.0% completed, USB
# 90.0% completed, UDR
# 91.0% completed, ULTA
# 91.0% completed, UAA
# 91.0% completed, UA
# 91.0% completed, UNP
# 91.0% completed, UAL
# 92.0% completed, UPS
# 92.0% completed, URI
# 92.0% completed, UNH
# 92.0% completed, UHS
# 92.0% completed, VLO
# 93.0% completed, VTR
# 93.0% completed, VRSN
# 93.0% completed, VRSK
# 93.0% completed, VZ
# 93.0% completed, VRTX
# 94.0% completed, VFC
# 94.0% completed, VIAC
# - VIAC: No data found, symbol may be delisted
# Error with:  VIAC
# 94.0% completed, VTRS
# 94.0% completed, V
# 94.0% completed, VNO
# 95.0% completed, VMC
# 95.0% completed, WRB
# 95.0% completed, GWW
# 95.0% completed, WAB
# 95.0% completed, WBA
# 96.0% completed, WMT
# 96.0% completed, WM
# 96.0% completed, WAT
# 96.0% completed, WEC
# 96.0% completed, WFC
# 97.0% completed, WELL
# 97.0% completed, WST
# 97.0% completed, WDC
# 97.0% completed, WU
# 97.0% completed, WRK
# 98.0% completed, WY
# 98.0% completed, WHR
# 98.0% completed, WMB
# 98.0% completed, WLTW
# - WLTW: No data found, symbol may be delisted
# Error with:  WLTW
# 98.0% completed, WYNN
# 99.0% completed, XEL
# 99.0% completed, XLNX
# - XLNX: No data found, symbol may be delisted
# Error with:  XLNX
# 99.0% completed, XYL
# 99.0% completed, YUM
# 99.0% completed, ZBRA
# 100.0% completed, ZBH
# 100.0% completed, ZION
# 100.0% completed, ZTS

# %% [markdown]
# ### Removing Low-Momentum Stocks
#
# The investment strategy that we're building seeks to identify the 50 highest momentum stocks in the S&P 500.
#
# Because of this, the next thing we need to do is to remove all stocks from `final_dataframe` that fall below this momentum threshold. We'll sort `final_dataframe` by the stocks one-tear price return, and drop all stocks outside the top 50.

# %%
## Sort the dataframe
final_dataframe.sort_values("One-YearPriceReturn", ascending=False, inplace=True)

## select the top 50
top_50 = final_dataframe[:50]

## reset index
top_50.reset_index(inplace=True, drop=True)

## view the top 50
top_50
# Out:
#     index  Unnamed: 0 Ticker       Price  One-YearPriceReturn  \
# 0     334         334    OXY   64.544998             0.913691
# 1     451         451    VLO  144.324997             0.902265
# 2     284         284    MPC  129.179092             0.882966
# 3     217         217    HES  152.940002             0.745513
# 4     162         162   ENPH  219.164993             0.710890
# 5     329         329    NUE  153.684998             0.639244
# 6     178         178    XOM  113.675003             0.623636
# 7     283         283    MRO   27.934999             0.545500
# 8     392         392    SLB   55.340000             0.534512
# 9     437         437   TWTR   53.700001             0.531660
# 10    294         294    MCK  376.480011             0.525067
# 11    372         372    PWR  151.354996             0.524846
# 12     82          82    CAH   74.824997             0.519897
# 13    268         268     LW   97.150002             0.518036
# 14    118         118    COP  119.014999             0.505578
# 15     43          43    APA   44.209999             0.473808
# 16     99          99    CVX  180.490005             0.470291
# 17    160         160    LLY  345.020111             0.454686
# 18    137         137    DVN   63.924999             0.429025
# 19    296         296    MRK  108.195000             0.416630
# 20    125         125   CTRA   25.264999             0.414872
# 21    211         211    HAL   39.610001             0.404726
# 22    164         164    EOG  132.789993             0.395155
# 23    442         442   ULTA  500.209991             0.371039
# 24    123         123   CTVA   62.355000             0.367167
# 25    412         412   TMUS  145.740005             0.366526
# 26    456         456   VRTX  312.250000             0.359500
# 27    353         353    PSX  106.525002             0.339271
# 28    227         227    HUM  500.662506             0.329447
# 29    103         103     CI  308.480011             0.326364
# 30    139         139   FANG  147.229996             0.315635
# 31    462         462    WRB   70.720001             0.298807
# 32     65          65   BIIB  291.125000             0.295674
# 33    360         360    PFG   89.669998             0.286289
# 34    207         207   GILD   83.809998             0.278028
# 35     48          48    AJG  197.220001             0.276834
# 36    355         355    PXD  237.169998             0.275382
# 37      7           7    ADM   85.559998             0.271089
# 38    341         341   PCAR  110.449997             0.264281
# 39    448         448    URI  394.519989             0.263718
# 40     95          95     CF   84.660004             0.258158
# 41    206         206    GPC  165.720001             0.258124
# 42    337         337    OKE   69.237503             0.255353
# 43     17          17    ALB  263.920013             0.253508
# 44    304         304   MRNA  196.289993             0.247870
# 45    395         395    SRE  159.190002             0.245121
# 46    427         427    MOS   48.180000             0.244488
# 47     36          36    ABC  161.419998             0.242463
# 48    171         171     RE  343.149994             0.235755
# 49    277         277    LMT  449.369995             0.235288
#
#     NumberSharesToBuy
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN

# %% [markdown]
# ### Calculating the Number of Shares to Buy
#
# We now need to calculate the number of shares we need to buy. We are going to wrap this functionality in a function, since we'll be using it again in the future. This portfolio will be equally weighted amongst the top50 stocks, as we haven't included marketCap.

# %%
def portfolio_size_input():
    # Get portfolio size
    portfolio_size = input("Enter the value of your portfolio:")
    try: 
        portfolio_size = float(portfolio_size)
    except ValueError:
        print("Portfolio Size is not a valid number.\n")

    return portfolio_size


def number_shares_to_buy(portfolio_size, portfolio):
    value = portfolio_size/50
    # loop through top_50 and place number of shares
    for i in range(0,len(portfolio)) :
        portfolio.loc[i,"NumberSharesToBuy"] = math.floor(value/portfolio.loc[i,"Price"])

# %% [markdown]
# We now use the functions to update our portfolio.

# %%
portfolio_size = portfolio_size_input()
number_shares_to_buy(portfolio_size, top_50)

top_50
# Out:
#     index  Unnamed: 0 Ticker       Price  One-YearPriceReturn  \
# 0     334         334    OXY   64.544998             0.913691
# 1     451         451    VLO  144.324997             0.902265
# 2     284         284    MPC  129.179092             0.882966
# 3     217         217    HES  152.940002             0.745513
# 4     162         162   ENPH  219.164993             0.710890
# 5     329         329    NUE  153.684998             0.639244
# 6     178         178    XOM  113.675003             0.623636
# 7     283         283    MRO   27.934999             0.545500
# 8     392         392    SLB   55.340000             0.534512
# 9     437         437   TWTR   53.700001             0.531660
# 10    294         294    MCK  376.480011             0.525067
# 11    372         372    PWR  151.354996             0.524846
# 12     82          82    CAH   74.824997             0.519897
# 13    268         268     LW   97.150002             0.518036
# 14    118         118    COP  119.014999             0.505578
# 15     43          43    APA   44.209999             0.473808
# 16     99          99    CVX  180.490005             0.470291
# 17    160         160    LLY  345.020111             0.454686
# 18    137         137    DVN   63.924999             0.429025
# 19    296         296    MRK  108.195000             0.416630
# 20    125         125   CTRA   25.264999             0.414872
# 21    211         211    HAL   39.610001             0.404726
# 22    164         164    EOG  132.789993             0.395155
# 23    442         442   ULTA  500.209991             0.371039
# 24    123         123   CTVA   62.355000             0.367167
# 25    412         412   TMUS  145.740005             0.366526
# 26    456         456   VRTX  312.250000             0.359500
# 27    353         353    PSX  106.525002             0.339271
# 28    227         227    HUM  500.662506             0.329447
# 29    103         103     CI  308.480011             0.326364
# 30    139         139   FANG  147.229996             0.315635
# 31    462         462    WRB   70.720001             0.298807
# 32     65          65   BIIB  291.125000             0.295674
# 33    360         360    PFG   89.669998             0.286289
# 34    207         207   GILD   83.809998             0.278028
# 35     48          48    AJG  197.220001             0.276834
# 36    355         355    PXD  237.169998             0.275382
# 37      7           7    ADM   85.559998             0.271089
# 38    341         341   PCAR  110.449997             0.264281
# 39    448         448    URI  394.519989             0.263718
# 40     95          95     CF   84.660004             0.258158
# 41    206         206    GPC  165.720001             0.258124
# 42    337         337    OKE   69.237503             0.255353
# 43     17          17    ALB  263.920013             0.253508
# 44    304         304   MRNA  196.289993             0.247870
# 45    395         395    SRE  159.190002             0.245121
# 46    427         427    MOS   48.180000             0.244488
# 47     36          36    ABC  161.419998             0.242463
# 48    171         171     RE  343.149994             0.235755
# 49    277         277    LMT  449.369995             0.235288
#
#     NumberSharesToBuy
# 0               309.0
# 1               138.0
# 2               154.0
# 3               130.0
# 4                91.0
# 5               130.0
# 6               175.0
# 7               715.0
# 8               361.0
# 9               372.0
# 10               53.0
# 11              132.0
# 12              267.0
# 13              205.0
# 14              168.0
# 15              452.0
# 16              110.0
# 17               57.0
# 18              312.0
# 19              184.0
# 20              791.0
# 21              504.0
# 22              150.0
# 23               39.0
# 24              320.0
# 25              137.0
# 26               64.0
# 27              187.0
# 28               39.0
# 29               64.0
# 30              135.0
# 31              282.0
# 32               68.0
# 33              223.0
# 34              238.0
# 35              101.0
# 36               84.0
# 37              233.0
# 38              181.0
# 39               50.0
# 40              236.0
# 41              120.0
# 42              288.0
# 43               75.0
# 44              101.0
# 45              125.0
# 46              415.0
# 47              123.0
# 48               58.0
# 49               44.0

# %% [markdown]
# ***
# ## Building a Better (and more realistic) Momemtum Strategy
#
# Real-world quantitative firms differentiate between "high quality" and "low quality" momentum stocks. These are defined as
#
# - High-quality momentum stocks show "slow and steady" outperformance over long periods of time.
# - Low-quality momentum stocks might not show any momentum for a long time, and then surge upwards.
#
# The reason why high-quality momentum stocks are preferred is because low-quality momentum can often be caused by short-term news that is unlikely to be repeated in the future (such as the FDA approving a biotech company).
#
# To identify high-quality momentum, we're going to build a strategy that selects stocks from the highest percentile of:
#
# - 1-month price returns
# - 3-month price returns
# - 6-month price returns
# - 1-year price returns
#
# Let's start by building our DataFrame. We use `hqm` for High Quality Momentum.

# %%
# Can Reload the old data here and skip to percentiles
hqm_df = pd.read_csv("HQM.csv", index_col=0)

# %%
hqm_columns = [
    "Ticker",
    "Price",
    "NumberSharesToBuy",
    "OneYearPriceReturn",
    "OneYearReturnPercentile",
    "SixMonthPriceReturn",
    "SixMonthReturnPercentile",
    "ThreeMonthPriceReturn",
    "ThreeMonthReturnPercentile",
    "OneMonthPriceReturn",
    "OneMonthReturnPercentile",
    "HQM Score"
]

hqm_df = pd.DataFrame(columns=hqm_columns)

# %% [markdown]
# We now loop through as before, completing the columns as we go.

# %%
## THIS CELL TAKES 7 MINS to RUN
i = 0
for tick in tickers:
    # Timer if wanted
    i += 1
    p = np.round((100*i)/len(tickers))
    print(f"{p}% completed,", tick)
    try:
        # Get data
        stock = yf.Ticker(tick)
        data = stock.history(period="1y", interval="1mo").Close
        data.dropna(axis=0, inplace=True)

        # one-year price return
        start_price = data[0]
        end_price = data[-1]
        one_year_price_return = (end_price - start_price)/start_price

        # six month price return
        start_price = data[-7]
        end_price = data[-1]
        six_month_price_return = (end_price - start_price)/start_price

        # three month price return
        start_price = data[-4]
        end_price = data[-1]
        three_month_price_return = (end_price - start_price)/start_price

        # one month price return
        start_price = data[-2]
        end_price = data[-1]
        one_month_price_return = (end_price - start_price)/start_price
        
        # update data frame
        row = pd.Series([tick, data[-1], "N/A", one_year_price_return, 'N/A', 
                                    six_month_price_return, "N/A",
                                    three_month_price_return, "N/A",
                                    one_month_price_return, "N/A", "N/A"], index = hqm_columns)
        hqm_df = pd.concat([hqm_df, row.to_frame().T], ignore_index=True)
    except:
        print("Error with: ", tick)

hqm_df.to_csv("HQM.csv")
# Out:
# 0.0% completed, MMM
# 0.0% completed, AOS
# 1.0% completed, ABT
# 1.0% completed, ABBV
# 1.0% completed, ABMD
# 1.0% completed, ACN
# 1.0% completed, ATVI
# 2.0% completed, ADM
# 2.0% completed, ADBE
# 2.0% completed, AAP
# 2.0% completed, AMD
# 2.0% completed, AES
# 3.0% completed, AFL
# 3.0% completed, A
# 3.0% completed, APD
# 3.0% completed, AKAM
# 3.0% completed, ALK
# 4.0% completed, ALB
# 4.0% completed, ARE
# 4.0% completed, ALGN
# 4.0% completed, ALLE
# 4.0% completed, LNT
# 5.0% completed, ALL
# 5.0% completed, GOOGL
# 5.0% completed, GOOG
# 5.0% completed, MO
# 5.0% completed, AMZN
# 6.0% completed, AMCR
# 6.0% completed, AEE
# 6.0% completed, AAL
# 6.0% completed, AEP
# 6.0% completed, AXP
# 7.0% completed, AIG
# 7.0% completed, AMT
# 7.0% completed, AWK
# 7.0% completed, AMP
# 7.0% completed, ABC
# 8.0% completed, AME
# 8.0% completed, AMGN
# 8.0% completed, APH
# 8.0% completed, ADI
# 8.0% completed, ANSS
# 9.0% completed, ANTM
# - ANTM: No data found, symbol may be delisted
# Error with:  ANTM
# 9.0% completed, AON
# 9.0% completed, APA
# 9.0% completed, AAPL
# 9.0% completed, AMAT
# 10.0% completed, APTV
# 10.0% completed, ANET
# 10.0% completed, AJG
# 10.0% completed, AIZ
# 10.0% completed, T
# 10.0% completed, ATO
# 11.0% completed, ADSK
# 11.0% completed, ADP
# 11.0% completed, AZO
# 11.0% completed, AVB
# 11.0% completed, AVY
# 12.0% completed, BKR
# 12.0% completed, BLL
# - BLL: No data found, symbol may be delisted
# Error with:  BLL
# 12.0% completed, BAC
# 12.0% completed, BBWI
# 12.0% completed, BAX
# 13.0% completed, BDX
# 13.0% completed, BRK.B
# - BRK.B: No data found, symbol may be delisted
# Error with:  BRK.B
# 13.0% completed, BBY
# 13.0% completed, BIO
# 13.0% completed, TECH
# 14.0% completed, BIIB
# 14.0% completed, BLK
# 14.0% completed, BK
# 14.0% completed, BA
# 14.0% completed, BKNG
# 15.0% completed, BWA
# 15.0% completed, BXP
# 15.0% completed, BSX
# 15.0% completed, BMY
# 15.0% completed, AVGO
# 16.0% completed, BR
# 16.0% completed, BRO
# 16.0% completed, BF.B
# - BF.B: No data found for this date range, symbol may be delisted
# Error with:  BF.B
# 16.0% completed, CHRW
# 16.0% completed, CDNS
# 17.0% completed, CZR
# 17.0% completed, CPB
# 17.0% completed, COF
# 17.0% completed, CAH
# 17.0% completed, KMX
# 18.0% completed, CCL
# 18.0% completed, CARR
# 18.0% completed, CTLT
# 18.0% completed, CAT
# 18.0% completed, CBOE
# 19.0% completed, CBRE
# 19.0% completed, CDW
# 19.0% completed, CE
# 19.0% completed, CNC
# 19.0% completed, CNP
# 20.0% completed, CDAY
# 20.0% completed, CERN
# - CERN: No data found, symbol may be delisted
# Error with:  CERN
# 20.0% completed, CF
# 20.0% completed, CRL
# 20.0% completed, SCHW
# 21.0% completed, CHTR
# 21.0% completed, CVX
# 21.0% completed, CMG
# 21.0% completed, CB
# 21.0% completed, CHD
# 22.0% completed, CI
# 22.0% completed, CINF
# 22.0% completed, CTAS
# 22.0% completed, CSCO
# 22.0% completed, C
# 23.0% completed, CFG
# 23.0% completed, CTXS
# - CTXS: No data found, symbol may be delisted
# Error with:  CTXS
# 23.0% completed, CLX
# 23.0% completed, CME
# 23.0% completed, CMS
# 24.0% completed, KO
# 24.0% completed, CTSH
# 24.0% completed, CL
# 24.0% completed, CMCSA
# 24.0% completed, CMA
# 25.0% completed, CAG
# 25.0% completed, COP
# 25.0% completed, ED
# 25.0% completed, STZ
# 25.0% completed, CPRT
# 26.0% completed, GLW
# 26.0% completed, CTVA
# 26.0% completed, COST
# 26.0% completed, CTRA
# 26.0% completed, CCI
# 27.0% completed, CSX
# 27.0% completed, CMI
# 27.0% completed, CVS
# 27.0% completed, DHI
# 27.0% completed, DHR
# 28.0% completed, DRI
# 28.0% completed, DVA
# 28.0% completed, DE
# 28.0% completed, DAL
# 28.0% completed, XRAY
# 29.0% completed, DVN
# 29.0% completed, DXCM
# 29.0% completed, FANG
# 29.0% completed, DLR
# 29.0% completed, DFS
# 30.0% completed, DISCA
# - DISCA: No data found, symbol may be delisted
# Error with:  DISCA
# 30.0% completed, DISCK
# - DISCK: No data found, symbol may be delisted
# Error with:  DISCK
# 30.0% completed, DISH
# 30.0% completed, DG
# 30.0% completed, DLTR
# 30.0% completed, D
# 31.0% completed, DPZ
# 31.0% completed, DOV
# 31.0% completed, DOW
# 31.0% completed, DTE
# 31.0% completed, DUK
# 32.0% completed, DRE
# - DRE: No data found, symbol may be delisted
# Error with:  DRE
# 32.0% completed, DD
# 32.0% completed, DXC
# 32.0% completed, EMN
# 32.0% completed, ETN
# 33.0% completed, EBAY
# 33.0% completed, ECL
# 33.0% completed, EIX
# 33.0% completed, EW
# 33.0% completed, EA
# 34.0% completed, LLY
# 34.0% completed, EMR
# 34.0% completed, ENPH
# 34.0% completed, ETR
# 34.0% completed, EOG
# 35.0% completed, EFX
# 35.0% completed, EQIX
# 35.0% completed, EQR
# 35.0% completed, ESS
# 35.0% completed, EL
# 36.0% completed, ETSY
# 36.0% completed, RE
# 36.0% completed, EVRG
# 36.0% completed, ES
# 36.0% completed, EXC
# 37.0% completed, EXPE
# 37.0% completed, EXPD
# 37.0% completed, EXR
# 37.0% completed, XOM
# 37.0% completed, FFIV
# 38.0% completed, FB
# - FB: No data found, symbol may be delisted
# Error with:  FB
# 38.0% completed, FAST
# 38.0% completed, FRT
# 38.0% completed, FDX
# 38.0% completed, FIS
# 39.0% completed, FITB
# 39.0% completed, FRC
# 39.0% completed, FE
# 39.0% completed, FISV
# 39.0% completed, FLT
# 40.0% completed, FMC
# 40.0% completed, F
# 40.0% completed, FTNT
# 40.0% completed, FTV
# 40.0% completed, FBHS
# 41.0% completed, FOXA
# 41.0% completed, FOX
# 41.0% completed, BEN
# 41.0% completed, FCX
# 41.0% completed, GPS
# 42.0% completed, GRMN
# 42.0% completed, IT
# 42.0% completed, GNRC
# 42.0% completed, GD
# 42.0% completed, GE
# 43.0% completed, GIS
# 43.0% completed, GM
# 43.0% completed, GPC
# 43.0% completed, GILD
# 43.0% completed, GPN
# 44.0% completed, GL
# 44.0% completed, GS
# 44.0% completed, HAL
# 44.0% completed, HBI
# 44.0% completed, HAS
# 45.0% completed, HCA
# 45.0% completed, PEAK
# 45.0% completed, HSIC
# 45.0% completed, HES
# 45.0% completed, HPE
# 46.0% completed, HLT
# 46.0% completed, HOLX
# 46.0% completed, HD
# 46.0% completed, HON
# 46.0% completed, HRL
# 47.0% completed, HST
# 47.0% completed, HWM
# 47.0% completed, HPQ
# 47.0% completed, HUM
# 47.0% completed, HBAN
# 48.0% completed, HII
# 48.0% completed, IBM
# 48.0% completed, IEX
# 48.0% completed, IDXX
# 48.0% completed, INFO
# - INFO: No data found, symbol may be delisted
# Error with:  INFO
# 49.0% completed, ITW
# 49.0% completed, ILMN
# 49.0% completed, INCY
# 49.0% completed, IR
# 49.0% completed, INTC
# 50.0% completed, ICE
# 50.0% completed, IFF
# 50.0% completed, IP
# 50.0% completed, IPG
# 50.0% completed, INTU
# 50.0% completed, ISRG
# 51.0% completed, IVZ
# 51.0% completed, IPGP
# 51.0% completed, IQV
# 51.0% completed, IRM
# 51.0% completed, JBHT
# 52.0% completed, JKHY
# 52.0% completed, J
# 52.0% completed, SJM
# 52.0% completed, JNJ
# 52.0% completed, JCI
# 53.0% completed, JPM
# 53.0% completed, JNPR
# 53.0% completed, KSU
# - KSU: No data found, symbol may be delisted
# Error with:  KSU
# 53.0% completed, K
# 53.0% completed, KEY
# 54.0% completed, KEYS
# 54.0% completed, KMB
# 54.0% completed, KIM
# 54.0% completed, KMI
# 54.0% completed, KLAC
# 55.0% completed, KHC
# 55.0% completed, KR
# 55.0% completed, LHX
# 55.0% completed, LH
# 55.0% completed, LRCX
# 56.0% completed, LW
# 56.0% completed, LVS
# 56.0% completed, LEG
# 56.0% completed, LDOS
# 56.0% completed, LEN
# 57.0% completed, LNC
# 57.0% completed, LIN
# 57.0% completed, LYV
# 57.0% completed, LKQ
# 57.0% completed, LMT
# 58.0% completed, L
# 58.0% completed, LOW
# 58.0% completed, LUMN
# 58.0% completed, LYB
# 58.0% completed, MTB
# 59.0% completed, MRO
# 59.0% completed, MPC
# 59.0% completed, MKTX
# 59.0% completed, MAR
# 59.0% completed, MMC
# 60.0% completed, MLM
# 60.0% completed, MAS
# 60.0% completed, MA
# 60.0% completed, MTCH
# 60.0% completed, MKC
# 61.0% completed, MCD
# 61.0% completed, MCK
# 61.0% completed, MDT
# 61.0% completed, MRK
# 61.0% completed, MET
# 62.0% completed, MTD
# 62.0% completed, MGM
# 62.0% completed, MCHP
# 62.0% completed, MU
# 62.0% completed, MSFT
# 63.0% completed, MAA
# 63.0% completed, MRNA
# 63.0% completed, MHK
# 63.0% completed, TAP
# 63.0% completed, MDLZ
# 64.0% completed, MPWR
# 64.0% completed, MNST
# 64.0% completed, MCO
# 64.0% completed, MS
# 64.0% completed, MSI
# 65.0% completed, MSCI
# 65.0% completed, NDAQ
# 65.0% completed, NTAP
# 65.0% completed, NFLX
# 65.0% completed, NWL
# 66.0% completed, NEM
# 66.0% completed, NWSA
# 66.0% completed, NWS
# 66.0% completed, NEE
# 66.0% completed, NLSN
# - NLSN: No data found, symbol may be delisted
# Error with:  NLSN
# 67.0% completed, NKE
# 67.0% completed, NI
# 67.0% completed, NSC
# 67.0% completed, NTRS
# 67.0% completed, NOC
# 68.0% completed, NLOK
# - NLOK: No data found, symbol may be delisted
# Error with:  NLOK
# 68.0% completed, NCLH
# 68.0% completed, NRG
# 68.0% completed, NUE
# 68.0% completed, NVDA
# 69.0% completed, NVR
# 69.0% completed, NXPI
# 69.0% completed, ORLY
# 69.0% completed, OXY
# 69.0% completed, ODFL
# 70.0% completed, OMC
# 70.0% completed, OKE
# 70.0% completed, ORCL
# 70.0% completed, OGN
# 70.0% completed, OTIS
# 70.0% completed, PCAR
# 71.0% completed, PKG
# 71.0% completed, PH
# 71.0% completed, PAYX
# 71.0% completed, PAYC
# 71.0% completed, PYPL
# 72.0% completed, PENN
# 72.0% completed, PNR
# 72.0% completed, PBCT
# - PBCT: No data found, symbol may be delisted
# Error with:  PBCT
# 72.0% completed, PEP
# 72.0% completed, PKI
# 73.0% completed, PFE
# 73.0% completed, PM
# 73.0% completed, PSX
# 73.0% completed, PNW
# 73.0% completed, PXD
# 74.0% completed, PNC
# 74.0% completed, POOL
# 74.0% completed, PPG
# 74.0% completed, PPL
# 74.0% completed, PFG
# 75.0% completed, PG
# 75.0% completed, PGR
# 75.0% completed, PLD
# 75.0% completed, PRU
# 75.0% completed, PTC
# 76.0% completed, PEG
# 76.0% completed, PSA
# 76.0% completed, PHM
# 76.0% completed, PVH
# 76.0% completed, QRVO
# 77.0% completed, QCOM
# 77.0% completed, PWR
# 77.0% completed, DGX
# 77.0% completed, RL
# 77.0% completed, RJF
# 78.0% completed, RTX
# 78.0% completed, O
# 78.0% completed, REG
# 78.0% completed, REGN
# 78.0% completed, RF
# 79.0% completed, RSG
# 79.0% completed, RMD
# 79.0% completed, RHI
# 79.0% completed, ROK
# 79.0% completed, ROL
# 80.0% completed, ROP
# 80.0% completed, ROST
# 80.0% completed, RCL
# 80.0% completed, SPGI
# 80.0% completed, CRM
# 81.0% completed, SBAC
# 81.0% completed, SLB
# 81.0% completed, STX
# 81.0% completed, SEE
# 81.0% completed, SRE
# 82.0% completed, NOW
# 82.0% completed, SHW
# 82.0% completed, SPG
# 82.0% completed, SWKS
# 82.0% completed, SNA
# 83.0% completed, SO
# 83.0% completed, LUV
# 83.0% completed, SWK
# 83.0% completed, SBUX
# 83.0% completed, STT
# 84.0% completed, STE
# 84.0% completed, SYK
# 84.0% completed, SIVB
# 84.0% completed, SYF
# 84.0% completed, SNPS
# 85.0% completed, SYY
# 85.0% completed, TMUS
# 85.0% completed, TROW
# 85.0% completed, TTWO
# 85.0% completed, TPR
# 86.0% completed, TGT
# 86.0% completed, TEL
# 86.0% completed, TDY
# 86.0% completed, TFX
# 86.0% completed, TER
# 87.0% completed, TSLA
# 87.0% completed, TXN
# 87.0% completed, TXT
# 87.0% completed, COO
# 87.0% completed, HIG
# 88.0% completed, HSY
# 88.0% completed, MOS
# 88.0% completed, TRV
# 88.0% completed, DIS
# 88.0% completed, TMO
# 89.0% completed, TJX
# 89.0% completed, TSCO
# 89.0% completed, TT
# 89.0% completed, TDG
# 89.0% completed, TRMB
# 90.0% completed, TFC
# 90.0% completed, TWTR
# 90.0% completed, TYL
# 90.0% completed, TSN
# 90.0% completed, USB
# 90.0% completed, UDR
# 91.0% completed, ULTA
# 91.0% completed, UAA
# 91.0% completed, UA
# 91.0% completed, UNP
# 91.0% completed, UAL
# 92.0% completed, UPS
# 92.0% completed, URI
# 92.0% completed, UNH
# 92.0% completed, UHS
# 92.0% completed, VLO
# 93.0% completed, VTR
# 93.0% completed, VRSN
# 93.0% completed, VRSK
# 93.0% completed, VZ
# 93.0% completed, VRTX
# 94.0% completed, VFC
# 94.0% completed, VIAC
# - VIAC: No data found, symbol may be delisted
# Error with:  VIAC
# 94.0% completed, VTRS
# 94.0% completed, V
# 94.0% completed, VNO
# 95.0% completed, VMC
# 95.0% completed, WRB
# 95.0% completed, GWW
# 95.0% completed, WAB
# 95.0% completed, WBA
# 96.0% completed, WMT
# 96.0% completed, WM
# 96.0% completed, WAT
# 96.0% completed, WEC
# 96.0% completed, WFC
# 97.0% completed, WELL
# 97.0% completed, WST
# 97.0% completed, WDC
# 97.0% completed, WU
# 97.0% completed, WRK
# 98.0% completed, WY
# 98.0% completed, WHR
# 98.0% completed, WMB
# 98.0% completed, WLTW
# - WLTW: No data found, symbol may be delisted
# Error with:  WLTW
# 98.0% completed, WYNN
# 99.0% completed, XEL
# 99.0% completed, XLNX
# - XLNX: No data found, symbol may be delisted
# Error with:  XLNX
# 99.0% completed, XYL
# 99.0% completed, YUM
# 99.0% completed, ZBRA
# 100.0% completed, ZBH
# 100.0% completed, ZION
# 100.0% completed, ZTS

# %% [markdown]
# ### Calculating Momentum Percentiles
#
# we now need to calculate momentum percentiles scores for every stock in the dataframe. Mroe specifically, we need to compute percentile scores for the following metrics for every stock:
#
# - `OneYearPriceReturn`
# - `SixMonthPriceReturn`
# - `ThreeMonthPriceReturn`
# - `OneMonthPriceReturn`
#
# Here's how we do this:

# %%
time_periods = ["OneYear", "SixMonth", "ThreeMonth", "OneMonth"]

for row in hqm_df.index:
    for time_period in time_periods:
        percentile_col = f"{time_period}ReturnPercentile"
        compute_col = f"{time_period}PriceReturn"
        hqm_df.loc[row, percentile_col] = score(hqm_df[compute_col], hqm_df.loc[row, compute_col])/100

hqm_df
# Out:
#     Ticker       Price  NumberSharesToBuy  OneYearPriceReturn  \
# 0      MMM  115.000000                NaN           -0.193568
# 1      AOS   60.669998                NaN           -0.102064
# 2      ABT  112.529999                NaN           -0.050470
# 3     ABBV  147.690002                NaN            0.037503
# 4     ABMD  381.019989                NaN            0.226170
# ..     ...         ...                ...                 ...
# 482    YUM  128.509995                NaN            0.068528
# 483   ZBRA  310.079987                NaN           -0.249819
# 484    ZBH  125.480003                NaN            0.024626
# 485   ZION   51.770000                NaN           -0.249603
# 486    ZTS  165.889999                NaN           -0.136425
#
#      OneYearReturnPercentile  SixMonthPriceReturn  SixMonthReturnPercentile  \
# 0                   0.184805            -0.054760                  0.199179
# 1                   0.338809             0.081005                  0.544148
# 2                   0.418891             0.106409                  0.618070
# 3                   0.591376             0.120118                  0.655031
# 4                   0.913758             0.539413                  0.991786
# ..                       ...                  ...                       ...
# 482                 0.689938             0.166235                  0.759754
# 483                 0.117043             0.027980                  0.392197
# 484                 0.560575             0.185094                  0.790554
# 485                 0.119097            -0.044934                  0.223819
# 486                 0.275154             0.064544                  0.498973
#
#      ThreeMonthPriceReturn  ThreeMonthReturnPercentile  OneMonthPriceReturn  \
# 0                -0.076395                    0.090349            -0.062143
# 1                -0.001153                    0.498973             0.007640
# 2                 0.050748                    0.749487            -0.008512
# 3                -0.074985                    0.098563             0.003662
# 4                 0.551005                    1.000000             0.008550
# ..                     ...                         ...                  ...
# 482               0.003412                    0.531828             0.014526
# 483               0.147255                    0.946612            -0.024169
# 484               0.046777                    0.724846            -0.003653
# 485               0.007178                    0.552361            -0.016714
# 486               0.078758                    0.841889            -0.002820
#
#      OneMonthReturnPercentile  HQM Score
# 0                    0.004107        NaN
# 1                    0.751540        NaN
# 2                    0.273101        NaN
# 3                    0.636550        NaN
# 4                    0.767967        NaN
# ..                        ...        ...
# 482                  0.893224        NaN
# 483                  0.049281        NaN
# 484                  0.420945        NaN
# 485                  0.125257        NaN
# 486                  0.441478        NaN
#
# [487 rows x 12 columns]

# %% [markdown]
# ### Calculating the HQM Score
#
# We'll now calculate our `HQM Score`, which is the high-quality momentum score that we'll use to filter for stock.
#
# The `HQM Score` will be the arithmetic mean of the 4 momentum percentile scores that we calculated in the last section.

# %%
from statistics import mean 

for row in hqm_df.index:
    momentum_percentiles = []
    for time_period in time_periods:
        momentum_percentiles.append(hqm_df.loc[row, f"{time_period}ReturnPercentile"])
    
    ## compute mean of momemtum percentiles and then append to dataframe
    hqm_df.loc[row, "HQM Score"] = mean(momentum_percentiles)
    
hqm_df
# Out:
#     Ticker       Price  NumberSharesToBuy  OneYearPriceReturn  \
# 0      MMM  115.000000                NaN           -0.193568
# 1      AOS   60.669998                NaN           -0.102064
# 2      ABT  112.529999                NaN           -0.050470
# 3     ABBV  147.690002                NaN            0.037503
# 4     ABMD  381.019989                NaN            0.226170
# ..     ...         ...                ...                 ...
# 482    YUM  128.509995                NaN            0.068528
# 483   ZBRA  310.079987                NaN           -0.249819
# 484    ZBH  125.480003                NaN            0.024626
# 485   ZION   51.770000                NaN           -0.249603
# 486    ZTS  165.889999                NaN           -0.136425
#
#      OneYearReturnPercentile  SixMonthPriceReturn  SixMonthReturnPercentile  \
# 0                   0.184805            -0.054760                  0.199179
# 1                   0.338809             0.081005                  0.544148
# 2                   0.418891             0.106409                  0.618070
# 3                   0.591376             0.120118                  0.655031
# 4                   0.913758             0.539413                  0.991786
# ..                       ...                  ...                       ...
# 482                 0.689938             0.166235                  0.759754
# 483                 0.117043             0.027980                  0.392197
# 484                 0.560575             0.185094                  0.790554
# 485                 0.119097            -0.044934                  0.223819
# 486                 0.275154             0.064544                  0.498973
#
#      ThreeMonthPriceReturn  ThreeMonthReturnPercentile  OneMonthPriceReturn  \
# 0                -0.076395                    0.090349            -0.062143
# 1                -0.001153                    0.498973             0.007640
# 2                 0.050748                    0.749487            -0.008512
# 3                -0.074985                    0.098563             0.003662
# 4                 0.551005                    1.000000             0.008550
# ..                     ...                         ...                  ...
# 482               0.003412                    0.531828             0.014526
# 483               0.147255                    0.946612            -0.024169
# 484               0.046777                    0.724846            -0.003653
# 485               0.007178                    0.552361            -0.016714
# 486               0.078758                    0.841889            -0.002820
#
#      OneMonthReturnPercentile  HQM Score
# 0                    0.004107   0.119610
# 1                    0.751540   0.533368
# 2                    0.273101   0.514887
# 3                    0.636550   0.495380
# 4                    0.767967   0.918378
# ..                        ...        ...
# 482                  0.893224   0.718686
# 483                  0.049281   0.376283
# 484                  0.420945   0.624230
# 485                  0.125257   0.255133
# 486                  0.441478   0.514374
#
# [487 rows x 12 columns]

# %% [markdown]
# ### Selecting the 50 Best Momentum Stocks
#
# We now rank the dataframe by the `HQM Score` and pick out the top 50.

# %%
hqm_df.sort_values("HQM Score", ascending=False, inplace=True)

# take the top 50
hqm_df = hqm_df[:50]

# reset index
hqm_df.reset_index(inplace=True, drop=True)

hqm_df
# Out:
#    Ticker        Price  NumberSharesToBuy  OneYearPriceReturn  \
# 0     CAT   257.609985                NaN            0.405500
# 1     MPC   130.210007                NaN            0.715676
# 2    PCAR   111.080002                NaN            0.262352
# 3    ABMD   381.019989                NaN            0.226170
# 4     VLO   145.029999                NaN            0.798937
# 5     DHI    97.000000                NaN            0.149283
# 6    TWTR    53.700001                NaN            0.510549
# 7     LEN    99.089996                NaN            0.118628
# 8      LW    96.980003                NaN            0.479565
# 9      GE    80.699997                NaN            0.087026
# 10   ORCL    89.699997                NaN            0.201258
# 11    TJX    81.300003                NaN            0.252059
# 12    LVS    55.470001                NaN            0.294214
# 13    OMC    86.139999                NaN            0.067307
# 14    URI   393.799988                NaN            0.224426
# 15    APD   313.339996                NaN            0.360051
# 16   ROST   117.720001                NaN            0.305496
# 17    PHM    51.619999                NaN            0.054106
# 18    AFL    72.800003                NaN            0.222685
# 19     CB   228.350006                NaN            0.139555
# 20   MRNA   196.759995                NaN            0.280989
# 21     BA   211.979996                NaN            0.032337
# 22    TRV   193.250000                NaN            0.148733
# 23     RE   343.500000                NaN            0.178487
# 24   NFLX   363.829987                NaN           -0.077791
# 25    XOM   113.809998                NaN            0.508861
# 26    TDG   694.250000                NaN            0.071122
# 27    STT    87.029999                NaN            0.054644
# 28    JCI    68.059998                NaN            0.074346
# 29   ULTA   501.529999                NaN            0.339199
# 30   SBUX   106.639999                NaN            0.189394
# 31    UAL    49.299999                NaN            0.110360
# 32    WAB   104.989998                NaN            0.138500
# 33    AMP   341.000000                NaN            0.156820
# 34     GL   119.430000                NaN            0.192320
# 35   BKNG  2402.340088                NaN            0.105922
# 36   MNST   103.019997                NaN            0.220616
# 37    SLB    55.470001                NaN            0.434635
# 38    CMI   247.860001                NaN            0.247249
# 39     IR    56.380001                NaN            0.117826
# 40    PFG    89.769997                NaN            0.315432
# 41   INCY    83.639999                NaN            0.224597
# 42   GILD    84.019997                NaN            0.454535
# 43    HES   153.880005                NaN            0.542142
# 44    ROK   277.980011                NaN            0.062406
# 45   KLAC   423.140015                NaN            0.230000
# 46   HOLX    81.589996                NaN            0.146410
# 47   WYNN    99.129997                NaN            0.145747
# 48      T    19.160000                NaN            0.136459
# 49     BK    49.459999                NaN           -0.038241
#
#     OneYearReturnPercentile  SixMonthPriceReturn  SixMonthReturnPercentile  \
# 0                  0.977413             0.410700                  0.973306
# 1                  0.997947             0.308422                  0.934292
# 2                  0.936345             0.314360                  0.938398
# 3                  0.913758             0.539413                  0.991786
# 4                  1.000000             0.257898                  0.897331
# 5                  0.831622             0.371453                  0.960986
# 6                  0.993840             0.095471                  0.587269
# 7                  0.790554             0.285574                  0.921971
# 8                  0.987680             0.226567                  0.866530
# 9                  0.731006             0.410743                  0.975359
# 10                 0.887064             0.220488                  0.860370
# 11                 0.928131             0.315522                  0.940452
# 12                 0.940452             0.474090                  0.979466
# 13                 0.685832             0.312873                  0.936345
# 14                 0.907598             0.348445                  0.952772
# 15                 0.963039             0.256470                  0.895277
# 16                 0.946612             0.372926                  0.963039
# 17                 0.642710             0.278899                  0.909651
# 18                 0.903491             0.240326                  0.882957
# 19                 0.817248             0.217753                  0.850103
# 20                 0.938398             0.487563                  0.981520
# 21                 0.581109             0.322808                  0.942505
# 22                 0.829569             0.208351                  0.835729
# 23                 0.856263             0.291004                  0.928131
# 24                 0.373717             0.627438                  0.997947
# 25                 0.991786             0.211852                  0.845996
# 26                 0.702259             0.189226                  0.794661
# 27                 0.648871             0.296859                  0.932238
# 28                 0.716632             0.272629                  0.903491
# 29                 0.958932             0.194489                  0.809035
# 30                 0.872690             0.283026                  0.915811
# 31                 0.765914             0.408169                  0.971253
# 32                 0.815195             0.201605                  0.821355
# 33                 0.837782             0.283458                  0.919918
# 34                 0.880903             0.233372                  0.872690
# 35                 0.761807             0.280695                  0.911704
# 36                 0.901437             0.159743                  0.737166
# 37                 0.981520             0.465704                  0.977413
# 38                 0.921971             0.166081                  0.757700
# 39                 0.784394             0.191082                  0.800821
# 40                 0.950719             0.219881                  0.854209
# 41                 0.909651             0.187562                  0.792608
# 42                 0.983573             0.349891                  0.954825
# 43                 0.995893             0.281456                  0.913758
# 44                 0.675565             0.183939                  0.784394
# 45                 0.915811             0.238130                  0.880903
# 46                 0.825462             0.207667                  0.833676
# 47                 0.823409             0.636079                  1.000000
# 48                 0.809035             0.127816                  0.679671
# 49                 0.443532             0.210791                  0.843943
#
#     ThreeMonthPriceReturn  ThreeMonthReturnPercentile  OneMonthPriceReturn  \
# 0                0.094871                    0.880903             0.024292
# 1                0.075653                    0.833676             0.026245
# 2                0.082095                    0.852156             0.086357
# 3                0.551005                    1.000000             0.008550
# 4                0.093004                    0.876797             0.013629
# 5                0.131195                    0.936345             0.013796
# 6                0.290555                    0.995893             0.224909
# 7                0.128202                    0.930185             0.015995
# 8                0.119178                    0.921971             0.008842
# 9                0.203636                    0.979466             0.011659
# 10               0.084383                    0.860370             0.011985
# 11               0.019823                    0.618070             0.026904
# 12               0.184244                    0.965092             0.001444
# 13               0.089858                    0.872690             0.018926
# 14               0.115486                    0.911704             0.004515
# 15               0.015536                    0.601643             0.014965
# 16               0.003038                    0.523614             0.016756
# 17               0.156877                    0.952772             0.010967
# 18               0.018022                    0.613963             0.017613
# 19               0.043889                    0.706366             0.021289
# 20               0.118526                    0.917864            -0.000914
# 21               0.185040                    0.969199             0.009573
# 22               0.023184                    0.632444             0.036971
# 23               0.021655                    0.624230             0.013543
# 24               0.190816                    0.973306             0.017934
# 25               0.030413                    0.659138             0.009312
# 26               0.104614                    0.897331             0.013504
# 27               0.101237                    0.889117             0.009395
# 28               0.029944                    0.657084             0.019931
# 29               0.078930                    0.843943             0.002118
# 30               0.049441                    0.743326             0.004049
# 31               0.116142                    0.913758             0.000406
# 32               0.040197                    0.704312             0.011172
# 33               0.031450                    0.667351             0.007296
# 34              -0.002690                    0.486653             0.016892
# 35               0.155277                    0.950719             0.000316
# 36               0.001555                    0.509240             0.029068
# 37               0.079720                    0.845996            -0.006982
# 38              -0.006902                    0.453799             0.020546
# 39               0.045033                    0.714579             0.008767
# 40               0.008186                    0.558522             0.004813
# 41               0.049831                    0.745380             0.001917
# 42              -0.035445                    0.285421             0.009492
# 43               0.072265                    0.825462            -0.008250
# 44               0.056999                    0.774127             0.008563
# 45               0.079974                    0.848049            -0.005733
# 46               0.071297                    0.821355            -0.000490
# 47               0.184915                    0.967146            -0.011566
# 48               0.008126                    0.556468             0.017627
# 49               0.085772                    0.866530             0.010072
#
#     OneMonthReturnPercentile  HQM Score
# 0                   0.973306   0.951232
# 1                   0.975359   0.935318
# 2                   0.997947   0.931211
# 3                   0.767967   0.918378
# 4                   0.882957   0.914271
# 5                   0.887064   0.904004
# 6                   1.000000   0.894251
# 7                   0.911704   0.888604
# 8                   0.776181   0.888090
# 9                   0.843943   0.882444
# 10                  0.856263   0.866016
# 11                  0.977413   0.866016
# 12                  0.572895   0.864476
# 13                  0.950719   0.861396
# 14                  0.663244   0.858830
# 15                  0.903491   0.840862
# 16                  0.924025   0.839322
# 17                  0.835729   0.835216
# 18                  0.936345   0.834189
# 19                  0.963039   0.834189
# 20                  0.494867   0.833162
# 21                  0.804928   0.824435
# 22                  0.995893   0.823409
# 23                  0.880903   0.822382
# 24                  0.942505   0.821869
# 25                  0.788501   0.821355
# 26                  0.878850   0.818275
# 27                  0.792608   0.815708
# 28                  0.954825   0.808008
# 29                  0.585216   0.799281
# 30                  0.657084   0.797228
# 31                  0.535934   0.796715
# 32                  0.837782   0.794661
# 33                  0.747433   0.793121
# 34                  0.930185   0.792608
# 35                  0.533881   0.789528
# 36                  0.985626   0.783368
# 37                  0.320329   0.781314
# 38                  0.958932   0.773101
# 39                  0.774127   0.768480
# 40                  0.669405   0.758214
# 41                  0.583162   0.757700
# 42                  0.800821   0.756160
# 43                  0.283368   0.754620
# 44                  0.770021   0.751027
# 45                  0.357290   0.750513
# 46                  0.511294   0.747947
# 47                  0.197125   0.746920
# 48                  0.938398   0.745893
# 49                  0.821355   0.743840

# %% [markdown]
# ### Calculating the Number of Shares to Buy

# %%
portfolio_size = portfolio_size_input()
number_shares_to_buy(portfolio_size, hqm_df)

hqm_df
# Out:
#    Ticker        Price  NumberSharesToBuy  OneYearPriceReturn  \
# 0     CAT   257.609985               77.0            0.405500
# 1     MPC   130.210007              153.0            0.715676
# 2    PCAR   111.080002              180.0            0.262352
# 3    ABMD   381.019989               52.0            0.226170
# 4     VLO   145.029999              137.0            0.798937
# 5     DHI    97.000000              206.0            0.149283
# 6    TWTR    53.700001              372.0            0.510549
# 7     LEN    99.089996              201.0            0.118628
# 8      LW    96.980003              206.0            0.479565
# 9      GE    80.699997              247.0            0.087026
# 10   ORCL    89.699997              222.0            0.201258
# 11    TJX    81.300003              246.0            0.252059
# 12    LVS    55.470001              360.0            0.294214
# 13    OMC    86.139999              232.0            0.067307
# 14    URI   393.799988               50.0            0.224426
# 15    APD   313.339996               63.0            0.360051
# 16   ROST   117.720001              169.0            0.305496
# 17    PHM    51.619999              387.0            0.054106
# 18    AFL    72.800003              274.0            0.222685
# 19     CB   228.350006               87.0            0.139555
# 20   MRNA   196.759995              101.0            0.280989
# 21     BA   211.979996               94.0            0.032337
# 22    TRV   193.250000              103.0            0.148733
# 23     RE   343.500000               58.0            0.178487
# 24   NFLX   363.829987               54.0           -0.077791
# 25    XOM   113.809998              175.0            0.508861
# 26    TDG   694.250000               28.0            0.071122
# 27    STT    87.029999              229.0            0.054644
# 28    JCI    68.059998              293.0            0.074346
# 29   ULTA   501.529999               39.0            0.339199
# 30   SBUX   106.639999              187.0            0.189394
# 31    UAL    49.299999              405.0            0.110360
# 32    WAB   104.989998              190.0            0.138500
# 33    AMP   341.000000               58.0            0.156820
# 34     GL   119.430000              167.0            0.192320
# 35   BKNG  2402.340088                8.0            0.105922
# 36   MNST   103.019997              194.0            0.220616
# 37    SLB    55.470001              360.0            0.434635
# 38    CMI   247.860001               80.0            0.247249
# 39     IR    56.380001              354.0            0.117826
# 40    PFG    89.769997              222.0            0.315432
# 41   INCY    83.639999              239.0            0.224597
# 42   GILD    84.019997              238.0            0.454535
# 43    HES   153.880005              129.0            0.542142
# 44    ROK   277.980011               71.0            0.062406
# 45   KLAC   423.140015               47.0            0.230000
# 46   HOLX    81.589996              245.0            0.146410
# 47   WYNN    99.129997              201.0            0.145747
# 48      T    19.160000             1043.0            0.136459
# 49     BK    49.459999              404.0           -0.038241
#
#     OneYearReturnPercentile  SixMonthPriceReturn  SixMonthReturnPercentile  \
# 0                  0.977413             0.410700                  0.973306
# 1                  0.997947             0.308422                  0.934292
# 2                  0.936345             0.314360                  0.938398
# 3                  0.913758             0.539413                  0.991786
# 4                  1.000000             0.257898                  0.897331
# 5                  0.831622             0.371453                  0.960986
# 6                  0.993840             0.095471                  0.587269
# 7                  0.790554             0.285574                  0.921971
# 8                  0.987680             0.226567                  0.866530
# 9                  0.731006             0.410743                  0.975359
# 10                 0.887064             0.220488                  0.860370
# 11                 0.928131             0.315522                  0.940452
# 12                 0.940452             0.474090                  0.979466
# 13                 0.685832             0.312873                  0.936345
# 14                 0.907598             0.348445                  0.952772
# 15                 0.963039             0.256470                  0.895277
# 16                 0.946612             0.372926                  0.963039
# 17                 0.642710             0.278899                  0.909651
# 18                 0.903491             0.240326                  0.882957
# 19                 0.817248             0.217753                  0.850103
# 20                 0.938398             0.487563                  0.981520
# 21                 0.581109             0.322808                  0.942505
# 22                 0.829569             0.208351                  0.835729
# 23                 0.856263             0.291004                  0.928131
# 24                 0.373717             0.627438                  0.997947
# 25                 0.991786             0.211852                  0.845996
# 26                 0.702259             0.189226                  0.794661
# 27                 0.648871             0.296859                  0.932238
# 28                 0.716632             0.272629                  0.903491
# 29                 0.958932             0.194489                  0.809035
# 30                 0.872690             0.283026                  0.915811
# 31                 0.765914             0.408169                  0.971253
# 32                 0.815195             0.201605                  0.821355
# 33                 0.837782             0.283458                  0.919918
# 34                 0.880903             0.233372                  0.872690
# 35                 0.761807             0.280695                  0.911704
# 36                 0.901437             0.159743                  0.737166
# 37                 0.981520             0.465704                  0.977413
# 38                 0.921971             0.166081                  0.757700
# 39                 0.784394             0.191082                  0.800821
# 40                 0.950719             0.219881                  0.854209
# 41                 0.909651             0.187562                  0.792608
# 42                 0.983573             0.349891                  0.954825
# 43                 0.995893             0.281456                  0.913758
# 44                 0.675565             0.183939                  0.784394
# 45                 0.915811             0.238130                  0.880903
# 46                 0.825462             0.207667                  0.833676
# 47                 0.823409             0.636079                  1.000000
# 48                 0.809035             0.127816                  0.679671
# 49                 0.443532             0.210791                  0.843943
#
#     ThreeMonthPriceReturn  ThreeMonthReturnPercentile  OneMonthPriceReturn  \
# 0                0.094871                    0.880903             0.024292
# 1                0.075653                    0.833676             0.026245
# 2                0.082095                    0.852156             0.086357
# 3                0.551005                    1.000000             0.008550
# 4                0.093004                    0.876797             0.013629
# 5                0.131195                    0.936345             0.013796
# 6                0.290555                    0.995893             0.224909
# 7                0.128202                    0.930185             0.015995
# 8                0.119178                    0.921971             0.008842
# 9                0.203636                    0.979466             0.011659
# 10               0.084383                    0.860370             0.011985
# 11               0.019823                    0.618070             0.026904
# 12               0.184244                    0.965092             0.001444
# 13               0.089858                    0.872690             0.018926
# 14               0.115486                    0.911704             0.004515
# 15               0.015536                    0.601643             0.014965
# 16               0.003038                    0.523614             0.016756
# 17               0.156877                    0.952772             0.010967
# 18               0.018022                    0.613963             0.017613
# 19               0.043889                    0.706366             0.021289
# 20               0.118526                    0.917864            -0.000914
# 21               0.185040                    0.969199             0.009573
# 22               0.023184                    0.632444             0.036971
# 23               0.021655                    0.624230             0.013543
# 24               0.190816                    0.973306             0.017934
# 25               0.030413                    0.659138             0.009312
# 26               0.104614                    0.897331             0.013504
# 27               0.101237                    0.889117             0.009395
# 28               0.029944                    0.657084             0.019931
# 29               0.078930                    0.843943             0.002118
# 30               0.049441                    0.743326             0.004049
# 31               0.116142                    0.913758             0.000406
# 32               0.040197                    0.704312             0.011172
# 33               0.031450                    0.667351             0.007296
# 34              -0.002690                    0.486653             0.016892
# 35               0.155277                    0.950719             0.000316
# 36               0.001555                    0.509240             0.029068
# 37               0.079720                    0.845996            -0.006982
# 38              -0.006902                    0.453799             0.020546
# 39               0.045033                    0.714579             0.008767
# 40               0.008186                    0.558522             0.004813
# 41               0.049831                    0.745380             0.001917
# 42              -0.035445                    0.285421             0.009492
# 43               0.072265                    0.825462            -0.008250
# 44               0.056999                    0.774127             0.008563
# 45               0.079974                    0.848049            -0.005733
# 46               0.071297                    0.821355            -0.000490
# 47               0.184915                    0.967146            -0.011566
# 48               0.008126                    0.556468             0.017627
# 49               0.085772                    0.866530             0.010072
#
#     OneMonthReturnPercentile  HQM Score
# 0                   0.973306   0.951232
# 1                   0.975359   0.935318
# 2                   0.997947   0.931211
# 3                   0.767967   0.918378
# 4                   0.882957   0.914271
# 5                   0.887064   0.904004
# 6                   1.000000   0.894251
# 7                   0.911704   0.888604
# 8                   0.776181   0.888090
# 9                   0.843943   0.882444
# 10                  0.856263   0.866016
# 11                  0.977413   0.866016
# 12                  0.572895   0.864476
# 13                  0.950719   0.861396
# 14                  0.663244   0.858830
# 15                  0.903491   0.840862
# 16                  0.924025   0.839322
# 17                  0.835729   0.835216
# 18                  0.936345   0.834189
# 19                  0.963039   0.834189
# 20                  0.494867   0.833162
# 21                  0.804928   0.824435
# 22                  0.995893   0.823409
# 23                  0.880903   0.822382
# 24                  0.942505   0.821869
# 25                  0.788501   0.821355
# 26                  0.878850   0.818275
# 27                  0.792608   0.815708
# 28                  0.954825   0.808008
# 29                  0.585216   0.799281
# 30                  0.657084   0.797228
# 31                  0.535934   0.796715
# 32                  0.837782   0.794661
# 33                  0.747433   0.793121
# 34                  0.930185   0.792608
# 35                  0.533881   0.789528
# 36                  0.985626   0.783368
# 37                  0.320329   0.781314
# 38                  0.958932   0.773101
# 39                  0.774127   0.768480
# 40                  0.669405   0.758214
# 41                  0.583162   0.757700
# 42                  0.800821   0.756160
# 43                  0.283368   0.754620
# 44                  0.770021   0.751027
# 45                  0.357290   0.750513
# 46                  0.511294   0.747947
# 47                  0.197125   0.746920
# 48                  0.938398   0.745893
# 49                  0.821355   0.743840

# %% [markdown]
# ***
# ## Formatting the Excel Output
#
# We will use `xlsxwriter` library for Python to create our nicely formatted excel output.

# %%
writer = pd.ExcelWriter("high_quality_momentum_strategy.xlsx", engine="xlsxwriter")

hqm_df.to_excel(writer, sheet_name="High Quality Momentum Strategy", index=False)

# %% [markdown]
# ### Creating the Formats We'll Need For Our `.xlsx` File
#
# Formats include colors, fonts, and also symbols like `%` and `$`. We'll need four main formats for our excel documents:
# - string format for tickers
# - $XX.XX format for stock prices
# - $XX,XXX format for market capitalization
# - integer format for the number of shares to buy

# %%
background_color = "#0a0a23"
font_color = "ffffff"

string_format = writer.book.add_format(
    {
        "font_color" : font_color,
        "bg_color" : background_color,
        "border" : 1
    }
)

dollar_format = writer.book.add_format(
    {
        "num_format" : "$0.00",
        "font_color" : font_color,
        "bg_color" : background_color,
        "border" : 1
    }
)

integer_format = writer.book.add_format(
    {
        "num_format" : "0",
        "font_color" : font_color,
        "bg_color" : background_color,
        "border" : 1
    }
)

percent_format = writer.book.add_format(
    {
        "num_format" : "0.0%",
        "font_color" : font_color,
        "bg_color" : background_color,
        "border" : 1
    }
)

# %% [markdown]
# ### Applying the Formats to our Columns in our `.xlsx` File ###
#
# We can use `set_column` method applied to the `writer.book` object to apply formats to specific columns of our spreadsheets.

# %%
column_formats = {
    "A" : ["Ticker", string_format],
    "B" : ["Price", dollar_format],
    "C" : ["NumberSharesToBuy", integer_format],
    "D" : ["OneYearPriceReturn", percent_format], 
    "E" : ["OneYearReturnPercentile", percent_format],
    "F" : ["SixMonthPriceReturn", percent_format],
    "G" : ["SixMonthReturnPercentile", percent_format],
    "H" : ["ThreeMonthPriceReturn", percent_format],
    "I" : ["ThreeMonthReturnPercentile", percent_format],
    "J" : ["OneMonthPriceReturn", percent_format],
    "K" : ["OneMonthReturnPercentile", percent_format],
    "L" : ["HQM Score", percent_format]
}

for column in column_formats.keys():
    writer.sheets["High Quality Momentum Strategy"].set_column(f"{column}:{column}", 30, column_formats[column][1])
    # write headers
    writer.sheets["High Quality Momentum Strategy"].write(f"{column}1", column_formats[column][0], column_formats[column][1])

# %% [markdown]
# ### Saving Excel Output

# %%
writer.close()
